# %%
import os
import numpy as np
import tensorflow as tf
import h5py
import wandb
import matplotlib.pyplot as plt 
from tensorflow.keras.models import load_model
from dotenv import load_dotenv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import KLDivergence
from tensorflow.keras.callbacks import LearningRateScheduler

# %%
load_dotenv()  # Load environment variables from .env file
api_key = os.getenv("WANDB_API_KEY")

wandb.login(key=api_key)  # Login with the API key
wandb.init(project="LEC_FER2013", entity=os.getenv("WANDB_USERNAME"))
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Network error (ConnectionError), entering retry loop.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011288888888888475, max=1.0…
# Tracking run with wandb version 0.18.1
# Run data is saved locally in <code>e:\AI Researches\Light Emotion CNN\Code\wandb\run-20250106_190402-hh58lb5i</code>
# Syncing run <strong><a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/hh58lb5i' target="_blank">sleek-rain-40</a></strong> to <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013</a>
#  View run at <a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/hh58lb5i' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013/runs/hh58lb5i</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/nicholas66/LEC_FER2013/runs/hh58lb5i?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def load_data(hdf5_file, dataset_name_images, dataset_name_labels):
    with h5py.File(hdf5_file, 'r') as hf:
        data = np.array(hf[dataset_name_images])
        labels = np.array(hf[dataset_name_labels])
    return data, labels

# Load data
data, labels = load_data('output files/fer2013_processed.h5', 'fer2013_images', 'fer2013_labels')

# Print shapes to verify
print(f"Data shape: {data.shape}")
print(f"Labels shape: {labels.shape}")

# Ensure that data and labels are not empty
assert len(data) > 0, "Data is empty."
assert len(labels) > 0, "Labels are empty."

# Split data
X_train, X_val, y_train, y_val = train_test_split(
    data, 
    labels, 
    test_size=0.2, 
    stratify=labels
)

# Print shapes of the split data
print(f"Training data shape: {X_train.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Validation data shape: {X_val.shape}")
print(f"Validation labels shape: {y_val.shape}")
# Out:
# Data shape: (28709, 224, 224, 3)
# Labels shape: (28709,)
# Training data shape: (22967, 224, 224, 3)
# Training labels shape: (22967,)
# Validation data shape: (5742, 224, 224, 3)
# Validation labels shape: (5742,)

# %%
# Define the data augmentation transformations
train_datagen = ImageDataGenerator(
    rotation_range=20,         # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,     # Randomly shift images horizontally by up to 20% of the width
    height_shift_range=0.2,    # Randomly shift images vertically by up to 20% of the height
    shear_range=0.2,           # Randomly apply shearing transformation
    zoom_range=0.2,            # Randomly zoom images by up to 20%
    horizontal_flip=True,      # Randomly flip images horizontally
    fill_mode='nearest'        # Strategy for filling in newly created pixels
)

# Create data generator for training data
train_generator = train_datagen.flow(
    X_train,   # Training images
    y_train,   # Training labels
    batch_size=64  # Batch size for training
)

validation_datagen = ImageDataGenerator()

# Create data generator for validation data
validation_generator = validation_datagen.flow(
    X_val,  # Validation images
    y_val,  # Validation labels
    batch_size=64   # Batch size for validation
)

# %% [markdown]
# # Teacher Model

# %%
def create_teacher_model():
    # Load the local MobileNetV3 model
    model = load_model("Trained Model/Teacher_MobileNetV3Large_model.keras")
    model.trainable = False  # Freeze the model layers
    
    return model

# %% [markdown]
# # LEC Model (Student)

# %%
def create_student_model():
    # Load MobileNetV3 as base model
    base_model = MobileNetV3Small(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
    # Freeze initial layers
    for layer in base_model.layers:  # Adjust the range as needed
        layer.trainable = True
    
    # Build the custom top layers
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dropout(0.1),
        Dense(64, activation='relu'),
        Dropout(0.1),
        Dense(7, activation='softmax')  # Assuming 7 emotion classes
    ])

    return model

# %%
teacher_model = create_teacher_model()
student_model = create_student_model()

# Custom callback for WandB
class WandBCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        wandb.log({
            "Training Loss": logs.get("loss"),
            "Training Accuracy": logs.get("accuracy"),
            "Val Loss": logs.get("val_loss"),
            "Val Accuracy": logs.get("val_accuracy"),
            "epoch": epoch + 1
        })



        

# Define the knowledge distillation loss function
def knowledge_distillation_loss(y_true, y_pred, teacher_logits, T=3, alpha=0.5):
    
    # Hard loss (real labels)
    hard_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    # Soft loss (teacher predictions)
    soft_loss = KLDivergence()(
        tf.nn.softmax(teacher_logits / T),
        tf.nn.softmax(y_pred / T)
    )
    # Combined loss
    return alpha * hard_loss + (1 - alpha) * soft_loss

# %%
# reduce_lr = ReduceLROnPlateau(
#     monitor='val_loss',  # Metric to monitor, e.g., validation loss
#     factor=0.5,          # Factor by which the learning rate will be reduced
#     patience=5,          # Number of epochs with no improvement before reducing LR
#     min_lr=1e-8,         # Lower bound for the learning rate
# )

def scheduler(epoch, lr):
    if epoch > 0 and epoch % 20 == 0:  # Every 20 epochs
        return lr * 0.5                # Reduce LR by factor of 0.5
    return lr

reduce_lr = LearningRateScheduler(scheduler, verbose=1)

# %%
# Custom training step for batch-wise teacher logits
class CustomDistillationModel(tf.keras.Model):
    def __init__(self, student, teacher):
        super(CustomDistillationModel, self).__init__()
        self.student = student
        self.teacher = teacher

    def call(self, inputs, training=False):
        return self.student(inputs, training=training)

    def train_step(self, data):
        x, y_true = data
        
        # Get teacher predictions for the current batch
        teacher_logits = self.teacher(x, training=False)
        # tf.print("Sample teacher_logits:", teacher_logits[:5])

        with tf.GradientTape() as tape:
            # Student predictions
            y_pred = self.student(x, training=True)
            # Compute the KD loss
            loss = knowledge_distillation_loss(y_true, y_pred, teacher_logits)

        # Compute gradients and update weights
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update metrics (accuracy)
        self.compiled_metrics.update_state(y_true, y_pred)

        logs = {m.name: m.result() for m in self.metrics}

        return logs

# Create the custom KD model
distilled_model = CustomDistillationModel(student_model, teacher_model)

# Compile the student model (no need to modify the WandB callback)
distilled_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model as before

# %%
history = distilled_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    callbacks=[WandBCallback(), reduce_lr],  # Add reduce_lr callback here
    verbose=1
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/100
# e:\AI Researches\Light Emotion CNN\Code\myenv\lib\site-packages\keras\src\backend\tensorflow\trainer.py:578: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# e:\AI Researches\Light Emotion CNN\Code\myenv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 2:19:40 23s/step - accuracy: 0.0938 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 10:33 2s/step - accuracy: 0.1172 - loss: 0.1429  ━━━━━━━━━━━━━━━━━━━━ 11:53 2s/step - accuracy: 0.1319 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:24 2s/step - accuracy: 0.1449 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:49 2s/step - accuracy: 0.1515 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12
- loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 13:04 2s/step - accuracy: 0.8180 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:57 2s/step - accuracy: 0.8179 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:52 2s/step - accuracy: 0.8178 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:50 2s/step - accuracy: 0.8176 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:43 2s/step - accuracy: 0.8176 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:37 2s/step - accuracy: 0.8175 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:31 2s/step - accuracy: 0.8174 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:25 2s/step - accuracy: 0.8173 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:21 2s/step - accuracy: 0.8173 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:16 2s/step - accuracy: 0.8173 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:10 2s/step - accuracy: 0.8173 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:05 2s/step - accuracy: 0.8173 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:00 2s/step - accuracy: 0.8174 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:56 2s/step - accuracy: 0.8174 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:51 2s/step - accuracy: 0.8174 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:45 2s/step - accuracy: 0.8175 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:38 2s/step - accuracy: 0.8175 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:33 2s/step - accuracy: 0.8175 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:27 2s/step - accuracy: 0.8176 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:21 2s/step - accuracy: 0.8176 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:16 2s/step - accuracy: 0.8177 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:11 2s/step - accuracy: 0.8178 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:06 2s/step - accuracy: 0.8178 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:01 2s/step - accuracy: 0.8179 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:56 2s/step - accuracy: 0.8179 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:51 2s/step - accuracy: 0.8179 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - ac ...
#
# Epoch 99: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 99/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 26:00 4s/step - accuracy: 0.7812 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.8086 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.8168 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.8197 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.8239 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.8254 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.8242 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.8237 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.8233 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.8230 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.8228 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.8228 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.8227 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.8227 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.8227 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.8228 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.8228 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.8229 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - accuracy: 0.8230 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.8230 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.8227 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - accuracy: 0.8226 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.8225 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - accuracy: 0.8224 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.8223 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.8222 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.8222 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.8221 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.8220 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.8219 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - accuracy: 0.8219 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.8219 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.8219 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:02 2s/step - accuracy: 0.8218 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.8217 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.8216 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.8215 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.8214 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:52 2s/step - accuracy: 0.8213 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.8213 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:50 2s/step - accuracy: 0.8212 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - accuracy: 0.8212 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.8212 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.8211 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.8211 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:41 2s/step - accuracy: 0.8211 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.8210 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.8209 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.8209 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.8208 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:33 2s/step - accuracy: 0.8207 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - accuracy: 0.8206 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.8206 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:28 2s/step - accuracy: 0.8205 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:26 2s/step - accuracy: 0.8205 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:24 2s/step - accuracy: 0.8205 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:22 2s/step - accuracy: 0.8205 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:21 2s/step - accuracy: 0.8205 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:19 2s/step - accuracy: 0.8204 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:17 2s/step - ac ...
#
# Epoch 100: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 100/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 25:12 4s/step - accuracy: 0.8281 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - accuracy: 0.8047 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.7969 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:47 2s/step - accuracy: 0.7939 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:47 2s/step - accuracy: 0.7908 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.7883 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.7857 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.7849 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.7857 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.7871 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.7886 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.7893 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - accuracy: 0.7892 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.7889 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.7892 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.7894 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.7896 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.7897 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.7902 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.7908 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.7913 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.7918 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - accuracy: 0.7923 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.7927 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.7930 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.7932 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.7934 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.7936 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.7938 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - accuracy: 0.7941 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.7943 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:04 2s/step - accuracy: 0.7946 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.7949 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.7952 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.7955 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.7958 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.7961 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - accuracy: 0.7965 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.7969 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:52 2s/step - accuracy: 0.7972 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:50 2s/step - accuracy: 0.7975 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.7978 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:47 2s/step - accuracy: 0.7981 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.7984 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.7987 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.7989 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.7992 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - accuracy: 0.7994 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.7996 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:35 2s/step - accuracy: 0.7999 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.8001 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - accuracy: 0.8003 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:30 2s/step - accuracy: 0.8005 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.8007 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:27 2s/step - accuracy: 0.8009 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:25 2s/step - accuracy: 0.8011 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:23 2s/step - accuracy: 0.8013 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:22 2s/step - accuracy: 0.8015 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:20 2s/step - accuracy: 0.8017 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:18 2s/step - ac ...

# %%
student_model.save('Trained Model/LEC_model2.keras')

# %%
# Plotting training and validation accuracy
plt.figure(figsize=(10, 5))  # Create a new figure for the plot
plt.plot(history.history['accuracy'], label='Training Accuracy')  # Plot training accuracy
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Plot validation accuracy
plt.title('Training and Validation Accuracy')  # Title of the plot
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label
plt.legend()  # Show legend
plt.grid()  # Show grid
plt.show()  # Display the plot
