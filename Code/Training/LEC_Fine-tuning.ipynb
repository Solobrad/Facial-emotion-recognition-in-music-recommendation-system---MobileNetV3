# %%
import os
import numpy as np
import tensorflow as tf
import h5py
import wandb
import matplotlib.pyplot as plt 
from tensorflow.keras.models import load_model
from dotenv import load_dotenv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Layer, Dense, Dropout
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import KLDivergence
from tensorflow.keras.callbacks import LearningRateScheduler

# %%
load_dotenv()  # Load environment variables from .env file
api_key = os.getenv("WANDB_API_KEY")

wandb.login(key=api_key)  # Login with the API key
wandb.init(project="LEC_FER2013", entity=os.getenv("WANDB_USERNAME"))
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: nicholas66. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.1
# Run data is saved locally in <code>e:\AI Researches\Light Emotion CNN\Code\wandb\run-20250107_171604-5rgy9kl2</code>
# Syncing run <strong><a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/5rgy9kl2' target="_blank">divine-blaze-41</a></strong> to <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013</a>
#  View run at <a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/5rgy9kl2' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013/runs/5rgy9kl2</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/nicholas66/LEC_FER2013/runs/5rgy9kl2?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def load_data(hdf5_file, dataset_name_images, dataset_name_labels):
    with h5py.File(hdf5_file, 'r') as hf:
        data = np.array(hf[dataset_name_images])
        labels = np.array(hf[dataset_name_labels])
    return data, labels

# Load data
data, labels = load_data('../../Data/output files/fer2013_processed.h5', 'fer2013_images', 'fer2013_labels')

# Print shapes to verify
print(f"Data shape: {data.shape}")
print(f"Labels shape: {labels.shape}")

# Ensure that data and labels are not empty
assert len(data) > 0, "Data is empty."
assert len(labels) > 0, "Labels are empty."

# Split data
X_train, X_val, y_train, y_val = train_test_split(
    data, 
    labels, 
    test_size=0.2, 
    stratify=labels
)

# Print shapes of the split data
print(f"Training data shape: {X_train.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Validation data shape: {X_val.shape}")
print(f"Validation labels shape: {y_val.shape}")
# Out:
# Data shape: (28709, 224, 224, 3)
# Labels shape: (28709,)
# Training data shape: (22967, 224, 224, 3)
# Training labels shape: (22967,)
# Validation data shape: (5742, 224, 224, 3)
# Validation labels shape: (5742,)

# %%
# Define the data augmentation transformations
train_datagen = ImageDataGenerator(
    rotation_range=20,         # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,     # Randomly shift images horizontally by up to 20% of the width
    height_shift_range=0.2,    # Randomly shift images vertically by up to 20% of the height
    shear_range=0.2,           # Randomly apply shearing transformation
    zoom_range=0.2,            # Randomly zoom images by up to 20%
    horizontal_flip=True,      # Randomly flip images horizontally
    fill_mode='nearest'        # Strategy for filling in newly created pixels
)

# Create data generator for training data
train_generator = train_datagen.flow(
    X_train,   # Training images
    y_train,   # Training labels
    batch_size=64  # Batch size for training
)

validation_datagen = ImageDataGenerator()

# Create data generator for validation data
validation_generator = validation_datagen.flow(
    X_val,  # Validation images
    y_val,  # Validation labels
    batch_size=64   # Batch size for validation
)

# %% [markdown]
# # Teacher Model

# %%
def create_teacher_model():
    # Load the local MobileNetV3 model
    model = load_model("Trained Model/Teacher_MobileNetV3Large_model.keras")
    model.trainable = False  # Freeze the model layers
    
    return model

# %% [markdown]
# # LEC Model (PEFT)

# %%
# Custom Adapter Layer
class AdapterLayer(Layer):
    def __init__(self, input_dim, bottleneck_dim, **kwargs):
        super(AdapterLayer, self).__init__(**kwargs)
        # A small bottleneck layer to reduce dimensionality before expanding
        self.dense1 = Dense(bottleneck_dim, activation='relu')
        # Expansion layer to project back to original dimensions
        self.dense2 = Dense(input_dim, activation='relu')

    def call(self, inputs):
        # Pass through the adapter layers
        x = self.dense1(inputs)
        return self.dense2(x)

# %%
def create_student_model():
    # Load MobileNetV3 as base model
    base_model = MobileNetV3Small(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
    # Freeze initial layers
    for layer in base_model.layers:  # Adjust the range as needed
        layer.trainable = False
    
    # Build the custom top layers
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),

        # Adapter Layer: Bottleneck to reduce and then expand dimensions
        AdapterLayer(1024, 64),  # (1024 is output dimension of MobileNetV3 before pooling, 64 is the bottleneck dimension)
        
    
        Dense(128, activation='relu'),
        Dropout(0.1),
        Dense(64, activation='relu'),
        Dropout(0.1),
        Dense(7, activation='softmax')  # Assuming 7 emotion classes
    ])

    return model

# %%
teacher_model = create_teacher_model()
student_model = create_student_model()

# Custom callback for WandB
class WandBCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        wandb.log({
            "Training Loss": logs.get("loss"),
            "Training Accuracy": logs.get("accuracy"),
            "Val Loss": logs.get("val_loss"),
            "Val Accuracy": logs.get("val_accuracy"),
            "epoch": epoch + 1
        })



        

# Define the knowledge distillation loss function
def knowledge_distillation_loss(y_true, y_pred, teacher_logits, T=3, alpha=0.5):
    
    # Hard loss (real labels)
    hard_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    # Soft loss (teacher predictions)
    soft_loss = KLDivergence()(
        tf.nn.softmax(teacher_logits / T),
        tf.nn.softmax(y_pred / T)
    )
    # Combined loss
    return alpha * hard_loss + (1 - alpha) * soft_loss

# %%
# reduce_lr = ReduceLROnPlateau(
#     monitor='val_loss',  # Metric to monitor, e.g., validation loss
#     factor=0.5,          # Factor by which the learning rate will be reduced
#     patience=5,          # Number of epochs with no improvement before reducing LR
#     min_lr=1e-8,         # Lower bound for the learning rate
# )

def scheduler(epoch, lr):
    if epoch > 0 and epoch % 20 == 0:  # Every 20 epochs
        return lr * 0.5                # Reduce LR by factor of 0.5
    return lr

reduce_lr = LearningRateScheduler(scheduler, verbose=1)

# %%
# Custom training step for batch-wise teacher logits
class CustomDistillationModel(tf.keras.Model):
    def __init__(self, student, teacher):
        super(CustomDistillationModel, self).__init__()
        self.student = student
        self.teacher = teacher

    def call(self, inputs, training=False):
        return self.student(inputs, training=training)

    def train_step(self, data):
        x, y_true = data
        
        # Get teacher predictions for the current batch
        teacher_logits = self.teacher(x, training=False)
        # tf.print("Sample teacher_logits:", teacher_logits[:5])

        with tf.GradientTape() as tape:
            # Student predictions
            y_pred = self.student(x, training=True)
            # Compute the KD loss
            loss = knowledge_distillation_loss(y_true, y_pred, teacher_logits)

        # Compute gradients and update weights
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update metrics (accuracy)
        self.compiled_metrics.update_state(y_true, y_pred)

        logs = {m.name: m.result() for m in self.metrics}

        return logs

# Create the custom KD model
distilled_model = CustomDistillationModel(student_model, teacher_model)

# Compile the student model (no need to modify the WandB callback)
distilled_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model as before

# %%
history = distilled_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    callbacks=[WandBCallback(), reduce_lr],  # Add reduce_lr callback here
    verbose=1
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/100
# e:\AI Researches\Light Emotion CNN\Code\myenv\lib\site-packages\keras\src\backend\tensorflow\trainer.py:578: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# e:\AI Researches\Light Emotion CNN\Code\myenv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 2:10:34 22s/step - accuracy: 0.0625 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.0586 - loss: 0.1429    ━━━━━━━━━━━━━━━━━━━━ 11:30 2s/step - accuracy: 0.0564 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:53 2s/step - accuracy: 0.0618 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:55 2s/step - accuracy: 0.0657 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:57 2s/step - accuracy: 0.0704 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:35 2s/step - accuracy: 0.0737 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:18 2s/step - accuracy: 0.0765 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:07 2s/step - accuracy: 0.0784 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:01 2s/step - accuracy: 0.0801 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:52 2s/step - accuracy: 0.0815 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:45 2s/step - accuracy: 0.0835 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:37 2s/step - accuracy: 0.0850 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:32 2s/step - accuracy: 0.0870 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:27 2s/step - accuracy: 0.0888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - accuracy: 0.0909 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:21 2s/step - accuracy: 0.0928 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:19 2s/step - accuracy: 0.0948 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:14 2s/step - accuracy: 0.0968 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:10 2s/step - accuracy: 0.0986 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:06 2s/step - accuracy: 0.1004 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:02 2s/step - accuracy: 0.1022 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.1038 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - accuracy: 0.1056 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.1073 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.1089 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.1107 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.1125 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.1144 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.1161 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.1178 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.1194 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.1210 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.1226 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.1241 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.1256 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.1271 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.1285 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.1299 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.1312 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.1324 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.1336 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.1348 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.1359 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.1370 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.1381 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.1392 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.1403 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.1413 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.1423 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.1433 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.1442 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - accuracy: 0.1452 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - accuracy: 0.1461 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.1470 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.1479 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.1488 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.1497 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.1506 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/ ...
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 26:31 4s/step - accuracy: 0.3750 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.3633 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.3637 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.3636 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.3628 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.3613 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.3607 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.3606 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.3614 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.3621 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.3627 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:02 2s/step - accuracy: 0.3640 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.3649 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.3653 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - accuracy: 0.3656 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.3663 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.3671 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.3679 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.3685 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.3690 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.3695 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.3700 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.3706 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.3710 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - accuracy: 0.3715 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.3721 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.3727 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.3733 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.3739 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.3743 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.3746 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.3750 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.3754 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.3759 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.3764 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.3768 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.3771 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.3774 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.3777 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - accuracy: 0.3780 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.3783 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.3785 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.3786 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.3788 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.3790 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.3792 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.3794 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:52 2s/step - accuracy: 0.3795 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.3797 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.3798 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:47 2s/step - accuracy: 0.3800 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.3802 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.3803 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.3805 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.3807 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.3808 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.3809 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:35 2s/step - accuracy: 0.3811 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:33 2s/step - accuracy: 0.3812 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - a ...
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 26:08 4s/step - accuracy: 0.3594 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.4141 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.4340 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.4437 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.4462 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.4474 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.4495 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.4521 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.4540 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.4547 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.4548 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.4554 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.4562 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.4569 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.4568 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.4564 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - accuracy: 0.4560 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.4556 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.4554 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.4553 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.4550 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.4550 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.4549 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.4550 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.4551 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.4551 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.4552 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.4553 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.4554 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.4554 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - accuracy: 0.4555 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.4554 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - accuracy: 0.4554 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:52 2s/step - accuracy: 0.4554 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.4555 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.4556 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - accuracy: 0.4557 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.4558 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.4559 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.4561 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.4562 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.4564 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.4565 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.4566 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:35 2s/step - accuracy: 0.4568 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.4569 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - accuracy: 0.4570 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:30 2s/step - accuracy: 0.4570 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.4571 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:27 2s/step - accuracy: 0.4571 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:25 2s/step - accuracy: 0.4571 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:24 2s/step - accuracy: 0.4572 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:22 2s/step - accuracy: 0.4573 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:21 2s/step - accuracy: 0.4574 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8
- loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.8046 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.8046 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.8046 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - accuracy: 0.8048 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.8049 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.8051 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.8052 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.8053 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.8054 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.8054 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:09 2s/step - accuracy: 0.8054 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - accuracy: 0.8055 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.8056 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.8056 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:02 2s/step - accuracy: 0.8056 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.8057 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.8057 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.8057 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - accuracy: 0.8058 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - accuracy: 0.8058 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.8058 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:50 2s/step - accuracy: 0.8059 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - accuracy: 0.8060 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.8060 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.8060 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.8061 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:41 2s/step - accuracy: 0.8061 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.8061 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - accuracy: 0.8061 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.8061 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.8061 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - accuracy: 0.8061 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - accuracy: 0.8061 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.8060 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:28 2s/step - accuracy: 0.8060 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:26 2s/step - accuracy: 0.8059 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:24 2s/step - accuracy: 0.8059 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:23 2s/step - accuracy: 0.8058 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:21 2s/step - ac ...
#
# Epoch 99: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 99/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 25:10 4s/step - accuracy: 0.8281 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.8281 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.8316 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.8298 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.8257 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.8222 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.8208 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.8195 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.8178 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.8158 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.8142 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.8133 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.8124 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.8110 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.8099 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.8091 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.8080 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.8072 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.8067 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.8062 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.8058 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.8053 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.8051 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.8048 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.8046 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.8044 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.8041 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.8039 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.8038 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:09 2s/step - accuracy: 0.8037 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.8037 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.8036 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:04 2s/step - accuracy: 0.8036 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:02 2s/step - accuracy: 0.8036 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.8035 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.8035 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.8036 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.8036 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.8035 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:52 2s/step - accuracy: 0.8035 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.8034 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.8033 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:47 2s/step - accuracy: 0.8032 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.8031 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - accuracy: 0.8030 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.8029 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.8028 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - accuracy: 0.8028 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.8027 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:35 2s/step - accuracy: 0.8026 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:33 2s/step - accuracy: 0.8026 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - accuracy: 0.8025 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:30 2s/step - accuracy: 0.8025 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.8025 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:27 2s/step - accuracy: 0.8024 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:25 2s/step - accuracy: 0.8024 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:24 2s/step - accuracy: 0.8024 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:23 2s/step - accuracy: 0.8023 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:22 2s/step - accuracy: 0.8022 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:20 2s/step - ac ...
#
# Epoch 100: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 100/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 25:57 4s/step - accuracy: 0.7969 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:12 2s/step - accuracy: 0.7969 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.7969 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.7969 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.7975 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.7974 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.7976 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.7966 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - accuracy: 0.7958 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.7952 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.7948 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.7946 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.7949 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.7953 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.7953 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.7955 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.7957 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.7958 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.7958 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.7959 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.7961 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.7964 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.7968 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.7971 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.7974 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.7976 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.7980 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.7984 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.7988 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - accuracy: 0.7992 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.7994 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.7996 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.7998 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.8000 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.8001 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.8003 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:09 2s/step - accuracy: 0.8004 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.8006 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.8007 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.8009 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.8010 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.8012 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.8014 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.8015 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - accuracy: 0.8016 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.8018 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:50 2s/step - accuracy: 0.8018 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.8019 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:47 2s/step - accuracy: 0.8020 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.8021 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - accuracy: 0.8022 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.8023 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:41 2s/step - accuracy: 0.8024 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.8026 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.8027 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.8028 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.8029 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - accuracy: 0.8030 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - accuracy: 0.8031 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - ac ...

# %%
student_model.save('Trained Model/LEC_PEFT.keras')

# %%
# Plotting training and validation accuracy
plt.figure(figsize=(10, 5))  # Create a new figure for the plot
plt.plot(history.history['accuracy'], label='Training Accuracy')  # Plot training accuracy
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Plot validation accuracy
plt.title('Training and Validation Accuracy')  # Title of the plot
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label
plt.legend()  # Show legend
plt.grid()  # Show grid
plt.show()  # Display the plot
