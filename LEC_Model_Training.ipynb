# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import gc
import h5py
import wandb
import sys
import matplotlib.pyplot as plt 
from tensorflow.keras.models import load_model
from dotenv import load_dotenv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras.applications import MobileNetV2, MobileNetV3Small, MobileNetV3Large
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import KLDivergence
from tensorflow.keras.layers import Input
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
load_dotenv()  # Load environment variables from .env file
api_key = os.getenv("WANDB_API_KEY")

wandb.login(key=api_key)  # Login with the API key
wandb.init(project="LEC_FER2013", entity=os.getenv("WANDB_USERNAME"))
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: nicholas66. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.1
# Run data is saved locally in <code>n:\Thesis 2\Code\wandb\run-20241202_180118-2h9q2b9n</code>
# Syncing run <strong><a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/2h9q2b9n' target="_blank">usual-rain-26</a></strong> to <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013</a>
#  View run at <a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/2h9q2b9n' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013/runs/2h9q2b9n</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/nicholas66/LEC_FER2013/runs/2h9q2b9n?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def load_data(hdf5_file, dataset_name_images, dataset_name_labels):
    with h5py.File(hdf5_file, 'r') as hf:
        data = np.array(hf[dataset_name_images])
        labels = np.array(hf[dataset_name_labels])
    return data, labels

# Load data
data, labels = load_data('output files/fer2013_processed.h5', 'fer2013_images', 'fer2013_labels')

# Print shapes to verify
print(f"Data shape: {data.shape}")
print(f"Labels shape: {labels.shape}")

# Ensure that data and labels are not empty
assert len(data) > 0, "Data is empty."
assert len(labels) > 0, "Labels are empty."

# Split data
X_train, X_val, y_train, y_val = train_test_split(
    data, 
    labels, 
    test_size=0.2, 
    stratify=labels
)

# Print shapes of the split data
print(f"Training data shape: {X_train.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Validation data shape: {X_val.shape}")
print(f"Validation labels shape: {y_val.shape}")
# Out:
# Data shape: (28709, 224, 224, 3)
# Labels shape: (28709,)
# Training data shape: (22967, 224, 224, 3)
# Training labels shape: (22967,)
# Validation data shape: (5742, 224, 224, 3)
# Validation labels shape: (5742,)

# %%
# Define the data augmentation transformations
train_datagen = ImageDataGenerator(
    rotation_range=20,         # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,     # Randomly shift images horizontally by up to 20% of the width
    height_shift_range=0.2,    # Randomly shift images vertically by up to 20% of the height
    shear_range=0.2,           # Randomly apply shearing transformation
    zoom_range=0.2,            # Randomly zoom images by up to 20%
    horizontal_flip=True,      # Randomly flip images horizontally
    fill_mode='nearest'        # Strategy for filling in newly created pixels
)

# Create data generator for training data
train_generator = train_datagen.flow(
    X_train,   # Training images
    y_train,   # Training labels
    batch_size=64  # Batch size for training
)

validation_datagen = ImageDataGenerator()

# Create data generator for validation data
validation_generator = validation_datagen.flow(
    X_val,  # Validation images
    y_val,  # Validation labels
    batch_size=64   # Batch size for validation
)

# %% [markdown]
# # Teacher Model

# %%
# def create_teacher_model():
#     base_model = EfficientNetB4(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#     base_model.trainable = False  # Freeze the EfficientNet model
    
#     # Build teacher model
#     model = Sequential([
#         base_model,
#         GlobalAveragePooling2D(),
#         Dense(128, activation='relu'),
#         Dense(64, activation='relu'),
#         Dense(7, activation='softmax')  # 7 emotion classes
#     ])
#     return model

def create_teacher_model():
    # Load the local MobileNetV3 model
    model = load_model("Trained Model/Teacher_MobileNetV3Large_model_no_lyrs.keras")
    model.trainable = False  # Freeze the model layers
    
    return model

# %% [markdown]
# # LEC Model (Student)

# %%
def create_student_model():
    # Load MobileNetV3 as base model
    base_model = MobileNetV3Small(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
    # Freeze initial layers
    for layer in base_model.layers:  # Adjust the range as needed
        layer.trainable = True
    
    # Build the custom top layers
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        Dense(7, activation='softmax')  # Assuming 7 emotion classes
    ])

    return model

# %%
teacher_model = create_teacher_model()
student_model = create_student_model()

# Custom callback for WandB
class WandBCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        wandb.log({
            "Training Loss": logs.get("loss"),
            "Training Accuracy": logs.get("accuracy"),
            "Val Loss": logs.get("val_loss"),
            "Val Accuracy": logs.get("val_accuracy"),
            "epoch": epoch + 1
        })



        

# Define the knowledge distillation loss function
def knowledge_distillation_loss(y_true, y_pred, teacher_logits, T=3, alpha=0.5):
    
    # Hard loss (real labels)
    hard_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    # Soft loss (teacher predictions)
    soft_loss = KLDivergence()(
        tf.nn.softmax(teacher_logits / T),
        tf.nn.softmax(y_pred / T)
    )
    # Combined loss
    return alpha * hard_loss + (1 - alpha) * soft_loss

# %%
# reduce_lr = ReduceLROnPlateau(
#     monitor='val_loss',  # Metric to monitor, e.g., validation loss
#     factor=0.5,          # Factor by which the learning rate will be reduced
#     patience=5,          # Number of epochs with no improvement before reducing LR
#     min_lr=1e-8,         # Lower bound for the learning rate
# )

from tensorflow.keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
    if epoch > 0 and epoch % 20 == 0:  # Every 20 epochs
        return lr * 0.5                # Reduce LR by factor of 0.5
    return lr

reduce_lr = LearningRateScheduler(scheduler, verbose=1)

# %%
# Custom training step for batch-wise teacher logits
class CustomDistillationModel(tf.keras.Model):
    def __init__(self, student, teacher):
        super(CustomDistillationModel, self).__init__()
        self.student = student
        self.teacher = teacher

    def call(self, inputs, training=False):
        return self.student(inputs, training=training)

    def train_step(self, data):
        x, y_true = data
        
        # Get teacher predictions for the current batch
        teacher_logits = self.teacher(x, training=False)
        # tf.print("Sample teacher_logits:", teacher_logits[:5])

        with tf.GradientTape() as tape:
            # Student predictions
            y_pred = self.student(x, training=True)
            # Compute the KD loss
            loss = knowledge_distillation_loss(y_true, y_pred, teacher_logits)

        # Compute gradients and update weights
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update metrics (accuracy)
        self.compiled_metrics.update_state(y_true, y_pred)

        logs = {m.name: m.result() for m in self.metrics}

        return logs

# Create the custom KD model
distilled_model = CustomDistillationModel(student_model, teacher_model)

# Compile the student model (no need to modify the WandB callback)
distilled_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model as before

# %%
history = distilled_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    callbacks=[WandBCallback(), reduce_lr],  # Add reduce_lr callback here
    verbose=1
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/100
# n:\Thesis 2\Code\myenv\lib\site-packages\keras\src\backend\tensorflow\trainer.py:578: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# n:\Thesis 2\Code\myenv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 2:06:57 21s/step - accuracy: 0.0781 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 10:38 2s/step - accuracy: 0.0898 - loss: 0.1429  ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - accuracy: 0.0981 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:07 2s/step - accuracy: 0.1029 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:09 2s/step - accuracy: 0.1060 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:09 2s/step - accuracy: 0.1075 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:07 2s/step - accuracy: 0.1093 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:07 2s/step - accuracy: 0.1098 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:06 2s/step - accuracy: 0.1100 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:04 2s/step - accuracy: 0.1096 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:03 2s/step - accuracy: 0.1093 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:04 2s/step - accuracy: 0.1099 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:03 2s/step - accuracy: 0.1104 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:02 2s/step - accuracy: 0.1109 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:00 2s/step - accuracy: 0.1117 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:58 2s/step - accuracy: 0.1121 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:57 2s/step - accuracy: 0.1126 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:54 2s/step - accuracy: 0.1128 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:52 2s/step - accuracy: 0.1130 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:51 2s/step - accuracy: 0.1133 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:48 2s/step - accuracy: 0.1136 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:46 2s/step - accuracy: 0.1139 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:45 2s/step - accuracy: 0.1141 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:40 2s/step - accuracy: 0.1145 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:38 2s/step - accuracy: 0.1150 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:37 2s/step - accuracy: 0.1154 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:35 2s/step - accuracy: 0.1159 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:33 2s/step - accuracy: 0.1165 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:32 2s/step - accuracy: 0.1170 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:31 2s/step - accuracy: 0.1175 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:29 2s/step - accuracy: 0.1180 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:27 2s/step - accuracy: 0.1185 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:25 2s/step - accuracy: 0.1191 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - accuracy: 0.1197 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - accuracy: 0.1203 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - accuracy: 0.1210 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.1216 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.1223 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:14 2s/step - accuracy: 0.1228 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:12 2s/step - accuracy: 0.1234 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:10 2s/step - accuracy: 0.1240 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.1246 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.1251 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.1256 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.1261 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:02 2s/step - accuracy: 0.1266 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.1271 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - accuracy: 0.1276 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.1280 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.1284 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.1288 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.1292 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.1296 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:47 2s/step - accuracy: 0.1300 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.1304 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.1308 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.1312 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.1316 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.1320 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/st ...
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 26:38 4s/step - accuracy: 0.3125 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:10 2s/step - accuracy: 0.2969 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:14 2s/step - accuracy: 0.2917 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:05 2s/step - accuracy: 0.2910 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:59 2s/step - accuracy: 0.2909 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:54 2s/step - accuracy: 0.2898 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:54 2s/step - accuracy: 0.2889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:50 2s/step - accuracy: 0.2894 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:46 2s/step - accuracy: 0.2908 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:44 2s/step - accuracy: 0.2923 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:41 2s/step - accuracy: 0.2933 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:41 2s/step - accuracy: 0.2938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:40 2s/step - accuracy: 0.2949 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:38 2s/step - accuracy: 0.2952 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:36 2s/step - accuracy: 0.2953 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:34 2s/step - accuracy: 0.2951 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:31 2s/step - accuracy: 0.2945 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:29 2s/step - accuracy: 0.2938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:27 2s/step - accuracy: 0.2931 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - accuracy: 0.2925 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - accuracy: 0.2921 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:19 2s/step - accuracy: 0.2917 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:17 2s/step - accuracy: 0.2914 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:15 2s/step - accuracy: 0.2911 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.2906 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:11 2s/step - accuracy: 0.2903 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.2903 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.2902 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.2902 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:02 2s/step - accuracy: 0.2902 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.2901 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - accuracy: 0.2901 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.2900 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.2900 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.2899 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.2900 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.2900 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.2901 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.2901 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.2901 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.2901 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.2901 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.2901 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.2901 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.2901 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.2902 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.2902 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.2903 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.2903 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.2904 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.2905 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.2906 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.2907 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.2908 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.2908 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.2909 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.2909 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.2910 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.2911 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - ac ...
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 24:55 4s/step - accuracy: 0.3125 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.3281 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.3438 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.3555 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.3606 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:14 2s/step - accuracy: 0.3656 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.3708 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:11 2s/step - accuracy: 0.3757 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.3783 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:08 2s/step - accuracy: 0.3808 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:06 2s/step - accuracy: 0.3817 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.3819 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.3818 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.3821 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.3821 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - accuracy: 0.3822 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.3825 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.3826 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - accuracy: 0.3829 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.3828 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.3828 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.3827 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.3828 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.3829 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.3830 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0
- loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:10 2s/step - accuracy: 0.5653 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:08 2s/step - accuracy: 0.5646 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:06 2s/step - accuracy: 0.5641 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.5644 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:02 2s/step - accuracy: 0.5642 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.5640 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.5640 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.5638 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - accuracy: 0.5636 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.5636 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.5637 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.5634 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:47 2s/step - accuracy: 0.5628 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.5626 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.5623 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.5619 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.5615 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.5612 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.5607 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.5604 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.5601 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.5597 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.5593 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.5590 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.5587 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.5584 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.5580 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.5577 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.5575 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.5572 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.5570 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.5569 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.5568 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.5568 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.5567 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.5566 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.5566 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.5564 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:04 2s/step - accuracy: 0.5563 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:02 2s/step - accuracy: 0.5562 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.5561 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.5560 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.5559 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.5558 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - accuracy: 0.5557 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - accuracy: 0.5557 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.5556 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:50 2s/step - ac ...
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 11/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 25:16 4s/step - accuracy: 0.5156 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:29 2s/step - accuracy: 0.5000 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:32 2s/step - accuracy: 0.4896 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:37 2s/step - accuracy: 0.4922 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:36 2s/step - accuracy: 0.4944 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:36 2s/step - accuracy: 0.4975 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:35 2s/step - accuracy: 0.5020 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:31 2s/step - accuracy: 0.5078 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:27 2s/step - accuracy: 0.5128 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:25 2s/step - accuracy: 0.5174 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - accuracy: 0.5215 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - accuracy: 0.5249 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:17 2s/step - accuracy: 0.5281 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.5312 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.5336 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:12 2s/step - accuracy: 0.5354 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:10 2s/step - accuracy: 0.5376 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.5394 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.5410 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.5424 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.5433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.5441 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.5448 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - accuracy: 0.5454 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.5458 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.5462 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.5465 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.5468 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.5472 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:47 2s/step - accuracy: 0.5477 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.5483 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.5488 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.5493 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.5497 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.5502 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.5506 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.5510 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.5513 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.5516 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.5519 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.5522 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.5524 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.5526 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.5529 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.5531 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.5533 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.5535 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.5536 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.5538 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.5539 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:09 2s/step - accuracy: 0.5539 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.5540 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - accuracy: 0.5540 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:04 2s/step - accuracy: 0.5540 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:02 2s/step - accuracy: 0.5541 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.5540 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.5540 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.5540 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - accuracy: 0.5541 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - ac ...
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 12/100
# ...
#
# Epoch 98: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 98/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 27:10 5s/step - accuracy: 0.6875 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:51 2s/step - accuracy: 0.6914 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:58 2s/step - accuracy: 0.7023 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - accuracy: 0.7074 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:57 2s/step - accuracy: 0.7153 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:01 2s/step - accuracy: 0.7215 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:02 2s/step - accuracy: 0.7256 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:01 2s/step - accuracy: 0.7298 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:59 2s/step - accuracy: 0.7334 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:57 2s/step - accuracy: 0.7366 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - accuracy: 0.7394 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:54 2s/step - accuracy: 0.7421 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:53 2s/step - accuracy: 0.7442 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:51 2s/step - accuracy: 0.7457 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:50 2s/step - accuracy: 0.7469 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:48 2s/step - accuracy: 0.7479 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:46 2s/step - accuracy: 0.7483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:44 2s/step - accuracy: 0.7483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:42 2s/step - accuracy: 0.7483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:39 2s/step - accuracy: 0.7483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:37 2s/step - accuracy: 0.7481 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:35 2s/step - accuracy: 0.7482 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:33 2s/step - accuracy: 0.7482 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:30 2s/step - accuracy: 0.7484 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:28 2s/step - accuracy: 0.7486 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:26 2s/step - accuracy: 0.7489 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - accuracy: 0.7490 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - accuracy: 0.7492 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - accuracy: 0.7492 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.7493 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.7493 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:15 2s/step - accuracy: 0.7493 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.7494 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:11 2s/step - accuracy: 0.7494 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.7493 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.7493 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.7494 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.7494 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.7495 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.7495 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - accuracy: 0.7496 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.7498 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.7499 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.7500 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.7501 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.7502 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.7502 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.7502 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.7502 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.7501 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.7500 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.7499 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - accuracy: 0.7498 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.7497 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.7496 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.7495 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.7495 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - accuracy: 0.7494 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.7493 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - ac ...
#
# Epoch 99: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 99/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 27:35 5s/step - accuracy: 0.7500 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:13 2s/step - accuracy: 0.7422 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:29 2s/step - accuracy: 0.7448 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:25 2s/step - accuracy: 0.7510 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:20 2s/step - accuracy: 0.7539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:14 2s/step - accuracy: 0.7559 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:09 2s/step - accuracy: 0.7579 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:05 2s/step - accuracy: 0.7581 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:03 2s/step - accuracy: 0.7580 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:03 2s/step - accuracy: 0.7574 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:59 2s/step - accuracy: 0.7572 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:58 2s/step - accuracy: 0.7566 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:56 2s/step - accuracy: 0.7558 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:52 2s/step - accuracy: 0.7551 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:50 2s/step - accuracy: 0.7546 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.7543 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:45 2s/step - accuracy: 0.7540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:42 2s/step - accuracy: 0.7539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:41 2s/step - accuracy: 0.7538 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:39 2s/step - accuracy: 0.7538 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:37 2s/step - accuracy: 0.7538 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:35 2s/step - accuracy: 0.7539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:33 2s/step - accuracy: 0.7540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:31 2s/step - accuracy: 0.7541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:29 2s/step - accuracy: 0.7542 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:27 2s/step - accuracy: 0.7543 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:25 2s/step - accuracy: 0.7544 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:23 2s/step - accuracy: 0.7543 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:21 2s/step - accuracy: 0.7542 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - accuracy: 0.7542 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.7541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.7541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:14 2s/step - accuracy: 0.7541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:12 2s/step - accuracy: 0.7540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:10 2s/step - accuracy: 0.7540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:08 2s/step - accuracy: 0.7540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:06 2s/step - accuracy: 0.7540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.7540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.7540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.7540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.7540 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.7540 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.7540 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.7540 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.7539 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.7538 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.7538 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.7537 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.7536 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.7536 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.7535 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.7535 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.7534 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.7533 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - accuracy: 0.7533 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.7532 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.7531 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.7530 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.7529 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - ac ...
#
# Epoch 100: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 100/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29:05 5s/step - accuracy: 0.7031 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:45 2s/step - accuracy: 0.7383 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - accuracy: 0.7405 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 13:13 2s/step - accuracy: 0.7419 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 14:07 2s/step - accuracy: 0.7441 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 13:31 2s/step - accuracy: 0.7464 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 13:06 2s/step - accuracy: 0.7498 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:49 2s/step - accuracy: 0.7532 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:33 2s/step - accuracy: 0.7548 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:21 2s/step - accuracy: 0.7557 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:12 2s/step - accuracy: 0.7558 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:05 2s/step - accuracy: 0.7560 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:57 2s/step - accuracy: 0.7556 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:51 2s/step - accuracy: 0.7552 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:46 2s/step - accuracy: 0.7546 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:41 2s/step - accuracy: 0.7541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:36 2s/step - accuracy: 0.7535 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:45 2s/step - accuracy: 0.7529 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:41 2s/step - accuracy: 0.7523 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:06 2s/step - accuracy: 0.7514 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:02 2s/step - accuracy: 0.7508 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:57 2s/step - accuracy: 0.7501 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:53 2s/step - accuracy: 0.7496 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:48 2s/step - accuracy: 0.7492 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:43 2s/step - accuracy: 0.7488 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:38 2s/step - accuracy: 0.7485 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:34 2s/step - accuracy: 0.7481 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:29 2s/step - accuracy: 0.7479 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:25 2s/step - accuracy: 0.7477 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:21 2s/step - accuracy: 0.7474 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:18 2s/step - accuracy: 0.7471 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:14 2s/step - accuracy: 0.7469 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:10 2s/step - accuracy: 0.7467 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:06 2s/step - accuracy: 0.7465 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:03 2s/step - accuracy: 0.7461 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:59 2s/step - accuracy: 0.7458 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - accuracy: 0.7456 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:52 2s/step - accuracy: 0.7454 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:48 2s/step - accuracy: 0.7453 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:45 2s/step - accuracy: 0.7451 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:42 2s/step - accuracy: 0.7449 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:39 2s/step - accuracy: 0.7447 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:36 2s/step - accuracy: 0.7446 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:33 2s/step - accuracy: 0.7445 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:30 2s/step - accuracy: 0.7444 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:27 2s/step - accuracy: 0.7442 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - accuracy: 0.7441 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:21 2s/step - accuracy: 0.7441 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:19 2s/step - accuracy: 0.7440 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.7439 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:12 2s/step - accuracy: 0.7438 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.7437 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.7436 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.7436 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.7435 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.7434 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.7433 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.7433 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.7432 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - ac ...

# %%
student_model.save('Trained Model/LEC_model_no_lyrs.keras')

# %%
# Plotting training and validation accuracy
plt.figure(figsize=(10, 5))  # Create a new figure for the plot
plt.plot(history.history['accuracy'], label='Training Accuracy')  # Plot training accuracy
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Plot validation accuracy
plt.title('Training and Validation Accuracy')  # Title of the plot
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label
plt.legend()  # Show legend
plt.grid()  # Show grid
plt.show()  # Display the plot
