# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import gc
import h5py
import wandb
import sys
import matplotlib.pyplot as plt 
from tensorflow.keras.models import load_model
from dotenv import load_dotenv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras.applications import MobileNetV2, MobileNetV3Small, MobileNetV3Large
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import KLDivergence
from tensorflow.keras.layers import Input
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
load_dotenv()  # Load environment variables from .env file
api_key = os.getenv("WANDB_API_KEY")

wandb.login(key=api_key)  # Login with the API key
wandb.init(project="LEC_FER2013", entity=os.getenv("WANDB_USERNAME"))
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: nicholas66. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.1
# Run data is saved locally in <code>n:\Thesis 2\Code\wandb\run-20241120_225807-xhrsslsj</code>
# Syncing run <strong><a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/xhrsslsj' target="_blank">dulcet-moon-24</a></strong> to <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013</a>
#  View run at <a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/xhrsslsj' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013/runs/xhrsslsj</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/nicholas66/LEC_FER2013/runs/xhrsslsj?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def load_data(hdf5_file, dataset_name_images, dataset_name_labels):
    with h5py.File(hdf5_file, 'r') as hf:
        data = np.array(hf[dataset_name_images])
        labels = np.array(hf[dataset_name_labels])
    return data, labels

# Load data
data, labels = load_data('output files/fer2013_processed.h5', 'fer2013_images', 'fer2013_labels')

# Print shapes to verify
print(f"Data shape: {data.shape}")
print(f"Labels shape: {labels.shape}")

# Ensure that data and labels are not empty
assert len(data) > 0, "Data is empty."
assert len(labels) > 0, "Labels are empty."

# Split data
X_train, X_val, y_train, y_val = train_test_split(
    data, 
    labels, 
    test_size=0.2, 
    stratify=labels
)

# Print shapes of the split data
print(f"Training data shape: {X_train.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Validation data shape: {X_val.shape}")
print(f"Validation labels shape: {y_val.shape}")
# Out:
# Data shape: (28709, 224, 224, 3)
# Labels shape: (28709,)
# Training data shape: (22967, 224, 224, 3)
# Training labels shape: (22967,)
# Validation data shape: (5742, 224, 224, 3)
# Validation labels shape: (5742,)

# %%
# Define the data augmentation transformations
train_datagen = ImageDataGenerator(
    rotation_range=20,         # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,     # Randomly shift images horizontally by up to 20% of the width
    height_shift_range=0.2,    # Randomly shift images vertically by up to 20% of the height
    shear_range=0.2,           # Randomly apply shearing transformation
    zoom_range=0.2,            # Randomly zoom images by up to 20%
    horizontal_flip=True,      # Randomly flip images horizontally
    fill_mode='nearest'        # Strategy for filling in newly created pixels
)

# Create data generator for training data
train_generator = train_datagen.flow(
    X_train,   # Training images
    y_train,   # Training labels
    batch_size=64  # Batch size for training
)

validation_datagen = ImageDataGenerator()

# Create data generator for validation data
validation_generator = validation_datagen.flow(
    X_val,  # Validation images
    y_val,  # Validation labels
    batch_size=64   # Batch size for validation
)

# %% [markdown]
# # Teacher Model

# %%
# def create_teacher_model():
#     base_model = EfficientNetB4(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#     base_model.trainable = False  # Freeze the EfficientNet model
    
#     # Build teacher model
#     model = Sequential([
#         base_model,
#         GlobalAveragePooling2D(),
#         Dense(128, activation='relu'),
#         Dense(64, activation='relu'),
#         Dense(7, activation='softmax')  # 7 emotion classes
#     ])
#     return model

def create_teacher_model():
    # Load the local MobileNetV3 model
    model = load_model("Trained Model/Teacher_MobileNetV3Large_model.keras")
    model.trainable = False  # Freeze the model layers
    
    return model

# %% [markdown]
# # LEC Model (Student)

# %%
def create_student_model():
    # Load MobileNetV3 as base model
    base_model = MobileNetV3Small(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
    # Freeze initial layers
    for layer in base_model.layers[:2]:  # Adjust the range as needed
        layer.trainable = False
    
    # Build the custom top layers
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        Dense(7, activation='softmax')  # Assuming 7 emotion classes
    ])

    return model

# %%
teacher_model = create_teacher_model()
student_model = create_student_model()

# Custom callback for WandB
class WandBCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        wandb.log({
            "Training Loss": logs.get("loss"),
            "Training Accuracy": logs.get("accuracy"),
            "Val Loss": logs.get("val_loss"),
            "Val Accuracy": logs.get("val_accuracy"),
            "epoch": epoch + 1
        })



        

# Define the knowledge distillation loss function
def knowledge_distillation_loss(y_true, y_pred, teacher_logits, T=3, alpha=0.5):
    
    # Hard loss (real labels)
    hard_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    # Soft loss (teacher predictions)
    soft_loss = KLDivergence()(
        tf.nn.softmax(teacher_logits / T),
        tf.nn.softmax(y_pred / T)
    )
    # Combined loss
    return alpha * hard_loss + (1 - alpha) * soft_loss

# %%
# reduce_lr = ReduceLROnPlateau(
#     monitor='val_loss',  # Metric to monitor, e.g., validation loss
#     factor=0.5,          # Factor by which the learning rate will be reduced
#     patience=5,          # Number of epochs with no improvement before reducing LR
#     min_lr=1e-8,         # Lower bound for the learning rate
# )

from tensorflow.keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
    if epoch > 0 and epoch % 20 == 0:  # Every 20 epochs
        return lr * 0.5                # Reduce LR by factor of 0.5
    return lr

reduce_lr = LearningRateScheduler(scheduler, verbose=1)

# %%
# Custom training step for batch-wise teacher logits
class CustomDistillationModel(tf.keras.Model):
    def __init__(self, student, teacher):
        super(CustomDistillationModel, self).__init__()
        self.student = student
        self.teacher = teacher

    def call(self, inputs, training=False):
        return self.student(inputs, training=training)

    def train_step(self, data):
        x, y_true = data
        
        # Get teacher predictions for the current batch
        teacher_logits = self.teacher(x, training=False)
        # tf.print("Sample teacher_logits:", teacher_logits[:5])

        with tf.GradientTape() as tape:
            # Student predictions
            y_pred = self.student(x, training=True)
            # Compute the KD loss
            loss = knowledge_distillation_loss(y_true, y_pred, teacher_logits)

        # Compute gradients and update weights
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update metrics (accuracy)
        self.compiled_metrics.update_state(y_true, y_pred)

        logs = {m.name: m.result() for m in self.metrics}

        return logs

# Create the custom KD model
distilled_model = CustomDistillationModel(student_model, teacher_model)

# Compile the student model (no need to modify the WandB callback)
distilled_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model as before

# %%
history = distilled_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    callbacks=[WandBCallback(), reduce_lr],  # Add reduce_lr callback here
    verbose=1
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch
- loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:19 2s/step - ac ...
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 11/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 24:52 4s/step - accuracy: 0.5938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.5859 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.5868 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.5856 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.5810 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.5792 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.5759 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.5737 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.5717 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.5709 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.5707 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.5698 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.5692 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.5684 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.5675 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.5667 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.5659 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.5653 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.5647 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - accuracy: 0.5642 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.5638 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.5634 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.5632 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.5629 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.5626 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.5623 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.5622 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.5621 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.5621 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:09 2s/step - accuracy: 0.5621 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.5622 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.5623 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.5624 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.5625 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.5625 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.5625 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.5625 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.5625 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:52 2s/step - accuracy: 0.5625 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.5626 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.5626 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:47 2s/step - accuracy: 0.5627 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.5628 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - accuracy: 0.5629 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.5629 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:41 2s/step - accuracy: 0.5629 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:33 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.5631 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:28 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:26 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:24 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:23 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:21 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:19 2s/step - accuracy: 0.5630 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:17 2s/step - ac ...
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 12/100
# ...
#
# Epoch 98: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 98/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28:51 5s/step - accuracy: 0.7344 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:43 2s/step - accuracy: 0.7305 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:53 2s/step - accuracy: 0.7387 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:06 2s/step - accuracy: 0.7415 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:17 2s/step - accuracy: 0.7414 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:20 2s/step - accuracy: 0.7389 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:17 2s/step - accuracy: 0.7382 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:14 2s/step - accuracy: 0.7375 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:07 2s/step - accuracy: 0.7377 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:03 2s/step - accuracy: 0.7379 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:58 2s/step - accuracy: 0.7381 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:58 2s/step - accuracy: 0.7381 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - accuracy: 0.7378 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:53 2s/step - accuracy: 0.7378 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:50 2s/step - accuracy: 0.7378 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.7379 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:44 2s/step - accuracy: 0.7377 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:40 2s/step - accuracy: 0.7372 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:37 2s/step - accuracy: 0.7369 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:34 2s/step - accuracy: 0.7365 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:32 2s/step - accuracy: 0.7362 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:30 2s/step - accuracy: 0.7361 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:30 2s/step - accuracy: 0.7359 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:29 2s/step - accuracy: 0.7358 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:27 2s/step - accuracy: 0.7359 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:25 2s/step - accuracy: 0.7361 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - accuracy: 0.7363 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - accuracy: 0.7365 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:21 2s/step - accuracy: 0.7366 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - accuracy: 0.7369 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.7371 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:17 2s/step - accuracy: 0.7373 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.7376 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:15 2s/step - accuracy: 0.7379 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.7383 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:12 2s/step - accuracy: 0.7386 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.7389 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.7391 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:02 2s/step - accuracy: 0.7393 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.7395 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.7397 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.7398 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.7400 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.7401 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.7403 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.7404 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.7405 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.7406 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - accuracy: 0.7407 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.7407 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.7408 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.7408 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.7408 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - accuracy: 0.7409 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.7409 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.7410 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.7410 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.7411 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.7411 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - ac ...
#
# Epoch 99: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 99/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29:37 5s/step - accuracy: 0.7500 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:47 2s/step - accuracy: 0.7656 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:04 2s/step - accuracy: 0.7812 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:00 2s/step - accuracy: 0.7783 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:02 2s/step - accuracy: 0.7777 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:04 2s/step - accuracy: 0.7739 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 12:00 2s/step - accuracy: 0.7711 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:52 2s/step - accuracy: 0.7680 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:43 2s/step - accuracy: 0.7654 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:34 2s/step - accuracy: 0.7625 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:27 2s/step - accuracy: 0.7603 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:21 2s/step - accuracy: 0.7590 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:17 2s/step - accuracy: 0.7580 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:11 2s/step - accuracy: 0.7563 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:07 2s/step - accuracy: 0.7549 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:05 2s/step - accuracy: 0.7538 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:01 2s/step - accuracy: 0.7527 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:58 2s/step - accuracy: 0.7519 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - accuracy: 0.7512 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:52 2s/step - accuracy: 0.7507 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:50 2s/step - accuracy: 0.7502 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.7498 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:44 2s/step - accuracy: 0.7493 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:42 2s/step - accuracy: 0.7489 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:39 2s/step - accuracy: 0.7487 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:37 2s/step - accuracy: 0.7486 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:35 2s/step - accuracy: 0.7485 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:33 2s/step - accuracy: 0.7484 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:30 2s/step - accuracy: 0.7482 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:28 2s/step - accuracy: 0.7481 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:26 2s/step - accuracy: 0.7479 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - accuracy: 0.7478 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - accuracy: 0.7477 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - accuracy: 0.7475 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:17 2s/step - accuracy: 0.7474 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:15 2s/step - accuracy: 0.7473 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.7472 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:10 2s/step - accuracy: 0.7471 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:08 2s/step - accuracy: 0.7471 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:06 2s/step - accuracy: 0.7470 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.7470 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:02 2s/step - accuracy: 0.7470 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.7470 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.7470 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - accuracy: 0.7471 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.7470 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.7469 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.7469 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:47 2s/step - accuracy: 0.7469 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.7468 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.7468 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.7469 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.7469 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.7469 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.7469 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - accuracy: 0.7468 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.7468 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.7468 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.7468 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - ac ...
#
# Epoch 100: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 100/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 32:06 5s/step - accuracy: 0.7344 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:41 2s/step - accuracy: 0.7305 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:35 2s/step - accuracy: 0.7405 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:50 2s/step - accuracy: 0.7477 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:47 2s/step - accuracy: 0.7494 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:51 2s/step - accuracy: 0.7508 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:51 2s/step - accuracy: 0.7517 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:51 2s/step - accuracy: 0.7519 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:53 2s/step - accuracy: 0.7511 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:54 2s/step - accuracy: 0.7495 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:51 2s/step - accuracy: 0.7484 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:48 2s/step - accuracy: 0.7471 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:45 2s/step - accuracy: 0.7461 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:45 2s/step - accuracy: 0.7452 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:48 2s/step - accuracy: 0.7443 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:48 2s/step - accuracy: 0.7441 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:48 2s/step - accuracy: 0.7438 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:47 2s/step - accuracy: 0.7438 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:45 2s/step - accuracy: 0.7437 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:45 2s/step - accuracy: 0.7437 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:48 2s/step - accuracy: 0.7434 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:53 2s/step - accuracy: 0.7432 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:52 2s/step - accuracy: 0.7430 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:49 2s/step - accuracy: 0.7428 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:50 2s/step - accuracy: 0.7427 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:52 2s/step - accuracy: 0.7426 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:50 2s/step - accuracy: 0.7427 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:45 2s/step - accuracy: 0.7428 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:43 2s/step - accuracy: 0.7429 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:41 2s/step - accuracy: 0.7431 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:39 2s/step - accuracy: 0.7432 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:36 2s/step - accuracy: 0.7432 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:32 2s/step - accuracy: 0.7431 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:29 2s/step - accuracy: 0.7430 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:27 2s/step - accuracy: 0.7430 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:26 2s/step - accuracy: 0.7430 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:24 2s/step - accuracy: 0.7430 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:20 2s/step - accuracy: 0.7430 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:16 2s/step - accuracy: 0.7430 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:14 2s/step - accuracy: 0.7430 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:11 2s/step - accuracy: 0.7431 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:10 2s/step - accuracy: 0.7431 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:06 2s/step - accuracy: 0.7433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:03 2s/step - accuracy: 0.7433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:00 2s/step - accuracy: 0.7433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:57 2s/step - accuracy: 0.7434 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:53 2s/step - accuracy: 0.7433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:50 2s/step - accuracy: 0.7433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.7433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:44 2s/step - accuracy: 0.7433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:41 2s/step - accuracy: 0.7433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:38 2s/step - accuracy: 0.7433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:34 2s/step - accuracy: 0.7434 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:31 2s/step - accuracy: 0.7435 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:29 2s/step - accuracy: 0.7436 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:26 2s/step - accuracy: 0.7437 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - accuracy: 0.7437 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - accuracy: 0.7438 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - accuracy: 0.7439 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - ac ...

# %%
student_model.save('Trained Model/LEC_model.keras')

# %%
# Plotting training and validation accuracy
plt.figure(figsize=(10, 5))  # Create a new figure for the plot
plt.plot(history.history['accuracy'], label='Training Accuracy')  # Plot training accuracy
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Plot validation accuracy
plt.title('Training and Validation Accuracy')  # Title of the plot
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label
plt.legend()  # Show legend
plt.grid()  # Show grid
plt.show()  # Display the plot
