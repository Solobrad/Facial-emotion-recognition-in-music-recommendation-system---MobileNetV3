# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import gc
import h5py
import wandb
import sys
from dotenv import load_dotenv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras.applications import MobileNetV2, MobileNetV3Small, MobileNetV3Large
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import KLDivergence
from tensorflow.keras.layers import Input

# %%
load_dotenv()  # Load environment variables from .env file
api_key = os.getenv("WANDB_API_KEY")

wandb.login(key=api_key)  # Login with the API key
wandb.init(project="LEC_FER2013", entity=os.getenv("WANDB_USERNAME"))
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: nicholas66. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.1
# Run data is saved locally in <code>n:\Thesis 2\Code\wandb\run-20241014_090617-3livdxlx</code>
# Syncing run <strong><a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/3livdxlx' target="_blank">olive-feather-9</a></strong> to <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013</a>
#  View run at <a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/3livdxlx' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013/runs/3livdxlx</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/nicholas66/LEC_FER2013/runs/3livdxlx?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def load_data(hdf5_file, dataset_name_images, dataset_name_labels):
    with h5py.File(hdf5_file, 'r') as hf:
        data = np.array(hf[dataset_name_images])
        labels = np.array(hf[dataset_name_labels])
    return data, labels

# Load data
data, labels = load_data('output files/fer2013_processed.h5', 'fer2013_images', 'fer2013_labels')

# Print shapes to verify
print(f"Data shape: {data.shape}")
print(f"Labels shape: {labels.shape}")

# Ensure that data and labels are not empty
assert len(data) > 0, "Data is empty."
assert len(labels) > 0, "Labels are empty."

# Split data
X_train, X_val, y_train, y_val = train_test_split(
    data, 
    labels, 
    test_size=0.2, 
    stratify=labels
)

# Print shapes of the split data
print(f"Training data shape: {X_train.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Validation data shape: {X_val.shape}")
print(f"Validation labels shape: {y_val.shape}")
# Out:
# Data shape: (28709, 224, 224, 3)
# Labels shape: (28709,)
# Training data shape: (22967, 224, 224, 3)
# Training labels shape: (22967,)
# Validation data shape: (5742, 224, 224, 3)
# Validation labels shape: (5742,)

# %%
# Define the data augmentation transformations
train_datagen = ImageDataGenerator(
    rotation_range=20,         # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,     # Randomly shift images horizontally by up to 20% of the width
    height_shift_range=0.2,    # Randomly shift images vertically by up to 20% of the height
    shear_range=0.2,           # Randomly apply shearing transformation
    zoom_range=0.2,            # Randomly zoom images by up to 20%
    horizontal_flip=True,      # Randomly flip images horizontally
    fill_mode='nearest'        # Strategy for filling in newly created pixels
)

# Create data generator for training data
train_generator = train_datagen.flow(
    X_train,   # Training images
    y_train,   # Training labels
    batch_size=64  # Batch size for training
)

validation_datagen = ImageDataGenerator()

# Create data generator for validation data
validation_generator = validation_datagen.flow(
    X_val,  # Validation images
    y_val,  # Validation labels
    batch_size=64   # Batch size for validation
)

# %% [markdown]
# # Teacher Model

# %%
def create_teacher_model():
    base_model = EfficientNetB4(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False  # Freeze the EfficientNet model
    
    # Build teacher model
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(7, activation='softmax')  # 7 emotion classes
    ])
    return model

# %% [markdown]
# # LEC Model (Student)

# %%
def create_student_model():
    # Load MobileNetV3 as base model
    base_model = MobileNetV3Small(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
    # Freeze initial layers
    for layer in base_model.layers[:3]:  # Adjust the range as needed
        layer.trainable = False
    
    # Build the custom top layers
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dropout(0.4),
        Dense(64, activation='relu'),
        Dropout(0.4),
        Dense(7, activation='softmax')  # Assuming 7 emotion classes
    ])

    return model

# %%
teacher_model = create_teacher_model()
student_model = create_student_model()

# Custom callback for WandB
class WandBCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        wandb.log({
            "Training Loss": logs.get("loss"),
            "Training Accuracy": logs.get("accuracy"),
            "Val Loss": logs.get("val_loss"),
            "Val Accuracy": logs.get("val_accuracy"),
            "epoch": epoch + 1 
        })

        

# Define the knowledge distillation loss function
def knowledge_distillation_loss(y_true, y_pred, teacher_logits, T=3, alpha=0.5):
    
    # Hard loss (real labels)
    hard_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    # Soft loss (teacher predictions)
    soft_loss = KLDivergence()(
        tf.nn.softmax(teacher_logits / T),
        tf.nn.softmax(y_pred / T)
    )
    # Combined loss
    return alpha * hard_loss + (1 - alpha) * soft_loss

# %%
# Custom training step for batch-wise teacher logits
class CustomDistillationModel(tf.keras.Model):
    def __init__(self, student, teacher):
        super(CustomDistillationModel, self).__init__()
        self.student = student
        self.teacher = teacher

    def call(self, inputs, training=False):
        return self.student(inputs, training=training)

    def train_step(self, data):
        x, y_true = data
        
        # Get teacher predictions for the current batch
        teacher_logits = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Student predictions
            y_pred = self.student(x, training=True)
            # Compute the KD loss
            loss = knowledge_distillation_loss(y_true, y_pred, teacher_logits)

        # Compute gradients and update weights
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update metrics (accuracy)
        self.compiled_metrics.update_state(y_true, y_pred)

        logs = {m.name: m.result() for m in self.metrics}

        return logs

# Create the custom KD model
distilled_model = CustomDistillationModel(student_model, teacher_model)

# Compile the student model (no need to modify the WandB callback)
distilled_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model as before

# %%
distilled_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    callbacks=[WandBCallback()],
    verbose=1
)
# Out:
# Epoch 1/100
# n:\Thesis 2\Code\myenv\lib\site-packages\keras\src\backend\tensorflow\trainer.py:578: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# n:\Thesis 2\Code\myenv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 3:09:16 32s/step - accuracy: 0.0938 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 21:10 4s/step - accuracy: 0.1016 - loss: 0.1429  ━━━━━━━━━━━━━━━━━━━━ 21:39 4s/step - accuracy: 0.1094 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:46 4s/step - accuracy: 0.1113 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:34 4s/step - accuracy: 0.1116 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:31 4s/step - accuracy: 0.1116 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:23 4s/step - accuracy: 0.1123 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:19 4s/step - accuracy: 0.1124 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:27 4s/step - accuracy: 0.1126 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:20 4s/step - accuracy: 0.1131 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:04 4s/step - accuracy: 0.1137 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:53 4s/step - accuracy: 0.1141 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:41 4s/step - accuracy: 0.1146 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:32 4s/step - accuracy: 0.1150 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:22 4s/step - accuracy: 0.1151 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:14 4s/step - accuracy: 0.1153 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:09 4s/step - accuracy: 0.1157 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:02 4s/step - accuracy: 0.1161 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:57 4s/step - accuracy: 0.1163 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:49 4s/step - accuracy: 0.1167 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:43 4s/step - accuracy: 0.1169 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:38 3s/step - accuracy: 0.1170 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:32 3s/step - accuracy: 0.1172 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:26 3s/step - accuracy: 0.1175 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:22 3s/step - accuracy: 0.1178 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:17 3s/step - accuracy: 0.1183 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:13 3s/step - accuracy: 0.1186 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:07 3s/step - accuracy: 0.1189 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:03 3s/step - accuracy: 0.1192 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:59 3s/step - accuracy: 0.1194 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:54 3s/step - accuracy: 0.1196 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:50 3s/step - accuracy: 0.1197 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:46 3s/step - accuracy: 0.1199 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:43 3s/step - accuracy: 0.1200 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:43 3s/step - accuracy: 0.1202 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:41 3s/step - accuracy: 0.1204 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:38 3s/step - accuracy: 0.1206 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:37 3s/step - accuracy: 0.1208 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:34 3s/step - accuracy: 0.1210 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:30 3s/step - accuracy: 0.1213 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:25 3s/step - accuracy: 0.1216 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:21 3s/step - accuracy: 0.1219 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:17 3s/step - accuracy: 0.1222 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:13 3s/step - accuracy: 0.1225 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:10 3s/step - accuracy: 0.1228 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:05 3s/step - accuracy: 0.1231 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:01 3s/step - accuracy: 0.1235 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:57 3s/step - accuracy: 0.1238 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:52 3s/step - accuracy: 0.1242 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:48 3s/step - accuracy: 0.1245 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:43 3s/step - accuracy: 0.1249 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:40 3s/step - accuracy: 0.1252 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:36 3s/step - accuracy: 0.1256 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:32 3s/step - accuracy: 0.1259 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:28 3s/step - accuracy: 0.1262 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:24 3s/step - accuracy: 0.1265 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:19 3s/step - accuracy: 0.1268 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:15 3s/step - accuracy: 0.1271 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:11 3s/step - accuracy: 0.1274 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:07 3s/st ...
# Epoch 2/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 44:31 7s/step - accuracy: 0.2500 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:28 4s/step - accuracy: 0.2383 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:55 4s/step - accuracy: 0.2283 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:23 3s/step - accuracy: 0.2308 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:04 3s/step - accuracy: 0.2296 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:52 3s/step - accuracy: 0.2274 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:42 3s/step - accuracy: 0.2265 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:34 3s/step - accuracy: 0.2265 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:28 3s/step - accuracy: 0.2262 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:22 3s/step - accuracy: 0.2261 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:17 3s/step - accuracy: 0.2263 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:12 3s/step - accuracy: 0.2272 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:08 3s/step - accuracy: 0.2289 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:03 3s/step - accuracy: 0.2301 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:58 3s/step - accuracy: 0.2310 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:54 3s/step - accuracy: 0.2320 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:50 3s/step - accuracy: 0.2330 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:54 3s/step - accuracy: 0.2340 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:53 3s/step - accuracy: 0.2348 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:51 3s/step - accuracy: 0.2356 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:51 3s/step - accuracy: 0.2363 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:49 3s/step - accuracy: 0.2370 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:48 3s/step - accuracy: 0.2378 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:49 3s/step - accuracy: 0.2385 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:49 3s/step - accuracy: 0.2391 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:45 3s/step - accuracy: 0.2397 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:43 3s/step - accuracy: 0.2403 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:41 3s/step - accuracy: 0.2409 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:39 3s/step - accuracy: 0.2416 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:37 3s/step - accuracy: 0.2422 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:35 3s/step - accuracy: 0.2428 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:33 3s/step - accuracy: 0.2434 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:31 3s/step - accuracy: 0.2439 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:29 3s/step - accuracy: 0.2445 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:27 3s/step - accuracy: 0.2450 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:25 3s/step - accuracy: 0.2455 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:22 3s/step - accuracy: 0.2459 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:19 3s/step - accuracy: 0.2463 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:17 3s/step - accuracy: 0.2467 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:12 3s/step - accuracy: 0.2471 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:10 3s/step - accuracy: 0.2474 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:08 3s/step - accuracy: 0.2478 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:07 3s/step - accuracy: 0.2481 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:05 3s/step - accuracy: 0.2485 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:04 3s/step - accuracy: 0.2488 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:01 3s/step - accuracy: 0.2492 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:57 3s/step - accuracy: 0.2495 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:54 3s/step - accuracy: 0.2498 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:51 3s/step - accuracy: 0.2502 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:47 3s/step - accuracy: 0.2505 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:44 3s/step - accuracy: 0.2509 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:40 3s/step - accuracy: 0.2512 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:37 3s/step - accuracy: 0.2514 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:33 3s/step - accuracy: 0.2517 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:30 3s/step - accuracy: 0.2519 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:26 3s/step - accuracy: 0.2521 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:21 3s/step - accuracy: 0.2523 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:17 3s/step - accuracy: 0.2525 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:13 3s/step - accuracy: 0.2527 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:09 3s/step - ac ...
# Epoch 3/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41:34 7s/step - accuracy: 0.2812 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:50 3s/step - accuracy: 0.2930 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:55 3s/step - accuracy: 0.3116 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:45 3s/step - accuracy: 0.3226 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:36 3s/step - accuracy: 0.3293 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:28 3s/step - accuracy: 0.3369 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:22 3s/step - accuracy: 0.3414 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:16 3s/step - accuracy: 0.3439 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:11 3s/step - accuracy: 0.3462 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:09 3s/step - accuracy: 0.3485 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:04 3s/step - accuracy: 0.3504 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:00 3s/step - accuracy: 0.3518 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:55 3s/step - accuracy: 0.3526 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:52 3s/step - accuracy: 0.3533 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:48 3s/step - accuracy: 0.3541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:45 3s/step - accuracy: 0.3547 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:41 3s/step - accuracy: 0.3551 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:38 3s/step - accuracy: 0.3552 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:35 3s/step - accuracy: 0.3554 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:31 3s/step - accuracy: 0.3555 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:27 3s/step - accuracy: 0.3556 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:25 3s/step - accuracy: 0.3555 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:22 3s/step - accuracy: 0.3552 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:20 3s/step - accuracy: 0.3550 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:19 3s/step - accuracy: 0.3548 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:15 3s/step - accuracy: 0.3547 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:12 3s/step - accuracy: 0.3545 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:08 3s/step - accuracy: 0.3543 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:05 3s/step - accuracy: 0.3543 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:02 3s/step - accuracy: 0.3542 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:58 3s/step - accuracy: 0.3541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:55 3s/step - accuracy: 0.3541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:51 3s/step - accuracy: 0.3541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:47 3s/step - accuracy: 0.3540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:44 3s/step - accuracy: 0.3540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:42 3s/step - accuracy: 0.3540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:38 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:35 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:32 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:30 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:27 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:25 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:22 3s/step - accuracy: 0.3538 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:20 3s/step - accuracy: 0.3538 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:18 3s/step - accuracy: 0.3538 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:15 3s/step - accuracy: 0.3538 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:12 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:08 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:05 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:01 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:58 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:54 3s/step - accuracy: 0.3539 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:50 3s/step - accuracy: 0.3540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:47 3s/step - accuracy: 0.3540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:44 3s/step - accuracy: 0.3540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:40 3s/step - accuracy: 0.3540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:37 3s/step - accuracy: 0.3541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:33 3s/step - accuracy: 0.3541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:30 3s/step - accuracy: 0.3541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:27 3s/step - ac ...
# Epoch 4/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40:04 7s/step - accuracy: 0.4219 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:18 3s/step - accuracy: 0.4102 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:22 3s/step - accuracy: 0.4036 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:37 3s/step - accuracy: 0.3955 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:44 4s/step - accuracy: 0.3927 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:53 4s/step - accuracy: 0.3932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:50 4s/step - accuracy: 0.3928 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:53 4s/step - accuracy: 0.3921 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:44 4s/step - accuracy: 0.3921 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:31 4s/step - accuracy: 0.3927 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:28 4s/step - accuracy: 0.3931 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:21 4s/step - accuracy: 0.3926 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:12 4s/step - accuracy: 0.3925 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:50 3s/step - accuracy: 0.3924 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:44 3s/step - accuracy: 0.3924 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:42 3s/step - accuracy: 0.3925 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:40 3s/step - accuracy: 0.3928 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:36 3s/step - accuracy: 0.3928 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:33 3s/step - accuracy: 0.3929 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:30 3s/step - accuracy: 0.3930 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:23 3s/step - accuracy: 0.3932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:18 3s/step - accuracy: 0.3931 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:13 3s/step - accuracy: 0.3932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:08 3s/step - accuracy: 0.3933 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:04 3s/step - accuracy: 0.3936 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:58 3s/step - accuracy: 0.3940 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:53 3s/step - accuracy: 0.3943 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:48 3s/step - accuracy: 0.3946 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:44 3s/step - accuracy: 0.3949 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:41 3s/step - accuracy: 0.3952 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:38 3s/step - accuracy: 0.3955 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:34 3s/step - accuracy: 0.3959 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:31 3s/step - accuracy: 0.3962 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:27 3s/step - accuracy: 0.3964 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:24 3s/step - accuracy: 0.3967 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:20 3s/step - accuracy: 0.3969 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:16 3s/step - accuracy: 0.3971 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:12 3s/step - accuracy: 0.3973 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:08 3s/step - accuracy: 0.3974 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:05 3s/step - accuracy: 0.3975 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:01 3s/step - accuracy: 0.3976 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:57 3s/step - accuracy: 0.3977 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:52 3s/step - accuracy: 0.3978 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:48 3s/step - accuracy: 0.3979 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:44 3s/step - accuracy: 0.3980 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:41 3s/step - accuracy: 0.3982 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:37 3s/step - accuracy: 0.3984 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:33 3s/step - accuracy: 0.3986 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:29 3s/step - accuracy: 0.3987 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:26 3s/step - accuracy: 0.3989 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:22 3s/step - accuracy: 0.3990 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:18 3s/step - accuracy: 0.3992 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:14 3s/step - accuracy: 0.3993 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:11 3s/step - accuracy: 0.3994 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:07 3s/step - accuracy: 0.3995 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:04 3s/step - accuracy: 0.3996 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:01 3s/step - accuracy: 0.3998 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:59 3s/step - accuracy: 0.3999 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:56 3s/step - accuracy: 0.4000 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:53 3s/step - ac ...
# Epoch 5/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 42:16 7s/step - accuracy: 0.4375 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:50 3s/step - accuracy: 0.4531 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:50 3s/step - accuracy: 0.4514 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:45 3s/step - accuracy: 0.4489 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:42 3s/step - accuracy: 0.4435 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:42 3s/step - accuracy: 0.4373 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:39 3s/step - accuracy: 0.4328 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:38 3s/step - accuracy: 0.4295 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:37 3s/step - accuracy: 0.4273 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:33 3s/step - accuracy: 0.4257 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:29 3s/step - accuracy: 0.4252 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:25 3s/step - accuracy: 0.4247 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:21 3s/step - accuracy: 0.4242 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:17 3s/step - accuracy: 0.4241 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:13 3s/step - accuracy: 0.4239 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:10 3s/step - accuracy: 0.4235 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:06 3s/step - accuracy: 0.4230 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:04 3s/step - accuracy: 0.4226 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:00 3s/step - accuracy: 0.4225 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:57 3s/step - accuracy: 0.4223 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:53 3s/step - accuracy: 0.4220 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:49 3s/step - accuracy: 0.4218 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:45 3s/step - accuracy: 0.4217 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:43 3s/step - accuracy: 0.4217 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:40 3s/step - accuracy: 0.4218 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:36 3s/step - accuracy: 0.4219 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:33 3s/step - accuracy: 0.4222 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:29 3s/step - accuracy: 0.4224 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:26 3s/step - accuracy: 0.4227 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:23 3s/step - accuracy: 0.4229 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:20 3s/step - accuracy: 0.4232 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:16 3s/step - accuracy: 0.4235 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:13 3s/step - accuracy: 0.4238 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:09 3s/step - accuracy: 0.4242 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:06 3s/step - accuracy: 0.4246 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:02 3s/step - accuracy: 0.4250 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:59 3s/step - accuracy: 0.4253 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:56 3s/step - accuracy: 0.4256 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:52 3s/step - accuracy: 0.4259 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:49 3s/step - accuracy: 0.4262 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:46 3s/step - accuracy: 0.4266 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:42 3s/step - accuracy: 0.4270 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:39 3s/step - accuracy: 0.4274 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:37 3s/step - accuracy: 0.4277 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:36 3s/step - accuracy: 0.4280 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:36 3s/step - accuracy: 0.4283 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:34 3s/step - accuracy: 0.4286 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:30 3s/step - accuracy: 0.4288 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:28 3s/step - accuracy: 0.4291 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:24 3s/step - accuracy: 0.4293 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:21 3s/step - accuracy: 0.4296 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:19 3s/step - accuracy: 0.4298 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:16 3s/step - accuracy: 0.4300 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:15 3s/step - accuracy: 0.4302 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:12 3s/step - accuracy: 0.4304 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:09 3s/step - accuracy: 0.4305 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:07 3s/step - accuracy: 0.4307 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:04 3s/step - accuracy: 0.4309 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:01 3s/step - accuracy: 0.4311 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:58 3s/step - ac ...
# Epoch 6/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 39:55 7s/step - accuracy: 0.5625 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:06 3s/step - accuracy: 0.5508 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:39 3s/step - accuracy: 0.5408 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:28 3s/step - accuracy: 0.5345 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:21 3s/step - accuracy: 0.5289 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:16 3s/step - accuracy: 0.5232 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:10 3s/step - accuracy: 0.5195 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:06 3s/step - accuracy: 0.5176 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:02 3s/step - accuracy: 0.5153 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:57 3s/step - accuracy: 0.5129 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:52 3s/step - accuracy: 0.5116 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:49 3s/step - accuracy: 0.5093 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:44 3s/step - accuracy: 0.5074 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:41 3s/step - accuracy: 0.5060 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:37 3s/step - accuracy: 0.5044 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:34 3s/step - accuracy: 0.5029 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:30 3s/step - accuracy: 0.5017 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:26 3s/step - accuracy: 0.5006 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:22 3s/step - accuracy: 0.4995 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:19 3s/step - accuracy: 0.4989 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:15 3s/step - accuracy: 0.4984 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:12 3s/step - accuracy: 0.4976 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:08 3s/step - accuracy: 0.4970 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:05 3s/step - accuracy: 0.4965 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:03 3s/step - accuracy: 0.4961 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:00 3s/step - accuracy: 0.4958 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:58 3s/step - accuracy: 0.4956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:56 3s/step - accuracy: 0.4955 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:53 3s/step - accuracy: 0.4953 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:50 3s/step - accuracy: 0.4954 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:46 3s/step - accuracy: 0.4954 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:43 3s/step - accuracy: 0.4955 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:40 3s/step - accuracy: 0.4956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:37 3s/step - accuracy: 0.4956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:34 3s/step - accuracy: 0.4956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:32 3s/step - accuracy: 0.4956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:30 3s/step - accuracy: 0.4956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:26 3s/step - accuracy: 0.4955 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:24 3s/step - accuracy: 0.4955 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:20 3s/step - accuracy: 0.4954 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:17 3s/step - accuracy: 0.4954 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:14 3s/step - accuracy: 0.4954 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:12 3s/step - accuracy: 0.4953 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:09 3s/step - accuracy: 0.4952 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:07 3s/step - accuracy: 0.4951 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:05 3s/step - accuracy: 0.4950 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:05 3s/step - accuracy: 0.4950 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:03 3s/step - accuracy: 0.4949 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:01 3s/step - accuracy: 0.4948 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:01 3s/step - accuracy: 0.4947 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:59 3s/step - accuracy: 0.4946 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:58 3s/step - accuracy: 0.4945 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:56 3s/step - accuracy: 0.4944 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:54 3s/step - accuracy: 0.4943 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:51 3s/step - accuracy: 0.4942 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:48 3s/step - accuracy: 0.4942 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:45 3s/step - accuracy: 0.4941 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:42 3s/step - accuracy: 0.4940 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:39 3s/step - accuracy: 0.4939 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:35 3s/step - ac ...
# Epoch 7/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 42:37 7s/step - accuracy: 0.4688 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:18 3s/step - accuracy: 0.4922 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:26 3s/step - accuracy: 0.5000 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:20 3s/step - accuracy: 0.5049 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:14 3s/step - accuracy: 0.5064 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:10 3s/step - accuracy: 0.5045 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:10 3s/step - accuracy: 0.5032 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:06 3s/step - accuracy: 0.5011 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:01 3s/step - accuracy: 0.4994 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:59 3s/step - accuracy: 0.4976 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:56 3s/step - accuracy: 0.4967 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:54 3s/step - accuracy: 0.4953 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:59 3s/step - accuracy: 0.4947 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:57 3s/step - accuracy: 0.4942 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:53 3s/step - accuracy: 0.4938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:48 3s/step - accuracy: 0.4929 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:44 3s/step - accuracy: 0.4923 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:41 3s/step - accuracy: 0.4921 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:39 3s/step - accuracy: 0.4924 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:38 3s/step - accuracy: 0.4928 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:36 3s/step - accuracy: 0.4930 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:33 3s/step - accuracy: 0.4934 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:31 3s/step - accuracy: 0.4938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:28 3s/step - accuracy: 0.4944 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:29 3s/step - accuracy: 0.4949 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:29 3s/step - accuracy: 0.4954 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:28 3s/step - accuracy: 0.4958 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:29 3s/step - accuracy: 0.4962 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:30 3s/step - accuracy: 0.4965 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:31 3s/step - accuracy: 0.4968 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:30 3s/step - accuracy: 0.4970 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:30 3s/step - accuracy: 0.4973 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:33 3s/step - accuracy: 0.4975 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:36 3s/step - accuracy: 0.4976 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:37 3s/step - accuracy: 0.4978 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:42 3s/step - accuracy: 0.4979 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:47 3s/step - accuracy: 0.4979 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:52 3s/step - accuracy: 0.4980 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:53 3s/step - accuracy: 0.4980 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:53 3s/step - accuracy: 0.4981 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:50 3s/step - accuracy: 0.4981 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:46 3s/step - accuracy: 0.4981 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:44 3s/step - accuracy: 0.4981 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:40 3s/step - accuracy: 0.4982 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:38 3s/step - accuracy: 0.4982 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:34 3s/step - accuracy: 0.4983 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:29 3s/step - accuracy: 0.4983 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:25 3s/step - accuracy: 0.4984 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:21 3s/step - accuracy: 0.4984 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:18 3s/step - accuracy: 0.4985 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:15 3s/step - accuracy: 0.4985 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:12 3s/step - accuracy: 0.4986 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:08 3s/step - accuracy: 0.4986 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:05 3s/step - accuracy: 0.4986 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:02 3s/step - accuracy: 0.4986 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:59 3s/step - accuracy: 0.4986 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:55 3s/step - accuracy: 0.4986 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:52 3s/step - accuracy: 0.4987 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:49 3s/step - accuracy: 0.4987 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:46 3s/step - ac ...
# Epoch 8/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40:08 7s/step - accuracy: 0.5938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:36 3s/step - accuracy: 0.5664 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:31 3s/step - accuracy: 0.5582 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:31 3s/step - accuracy: 0.5563 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:28 3s/step - accuracy: 0.5569 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:24 3s/step - accuracy: 0.5596 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:21 3s/step - accuracy: 0.5610 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:18 3s/step - accuracy: 0.5614 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:16 3s/step - accuracy: 0.5608 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:12 3s/step - accuracy: 0.5601 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:09 3s/step - accuracy: 0.5589 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:06 3s/step - accuracy: 0.5579 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:02 3s/step - accuracy: 0.5569 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:59 3s/step - accuracy: 0.5559 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:56 3s/step - accuracy: 0.5551 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:52 3s/step - accuracy: 0.5543 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:50 3s/step - accuracy: 0.5533 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:47 3s/step - accuracy: 0.5524 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:44 3s/step - accuracy: 0.5517 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:41 3s/step - accuracy: 0.5510 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:37 3s/step - accuracy: 0.5507 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:35 3s/step - accuracy: 0.5503 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:31 3s/step - accuracy: 0.5500 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:28 3s/step - accuracy: 0.5499 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:25 3s/step - accuracy: 0.5495 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:22 3s/step - accuracy: 0.5490 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:19 3s/step - accuracy: 0.5484 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:15 3s/step - accuracy: 0.5479 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:12 3s/step - accuracy: 0.5474 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:09 3s/step - accuracy: 0.5470 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:06 3s/step - accuracy: 0.5466 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:03 3s/step - accuracy: 0.5463 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:00 3s/step - accuracy: 0.5461 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:57 3s/step - accuracy: 0.5458 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:54 3s/step - accuracy: 0.5456 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:50 3s/step - accuracy: 0.5453 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:47 3s/step - accuracy: 0.5450 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:44 3s/step - accuracy: 0.5446 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:41 3s/step - accuracy: 0.5443 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:38 3s/step - accuracy: 0.5440 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:35 3s/step - accuracy: 0.5437 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:32 3s/step - accuracy: 0.5434 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:29 3s/step - accuracy: 0.5431 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:27 3s/step - accuracy: 0.5428 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:24 3s/step - accuracy: 0.5425 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:21 3s/step - accuracy: 0.5423 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:18 3s/step - accuracy: 0.5420 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:16 3s/step - accuracy: 0.5418 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:13 3s/step - accuracy: 0.5416 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:10 3s/step - accuracy: 0.5414 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:07 3s/step - accuracy: 0.5412 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:04 3s/step - accuracy: 0.5411 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:01 3s/step - accuracy: 0.5409 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 15:59 3s/step - accuracy: 0.5407 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 15:55 3s/step - accuracy: 0.5406 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 15:52 3s/step - accuracy: 0.5405 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 15:49 3s/step - accuracy: 0.5404 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 15:46 3s/step - accuracy: 0.5403 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 15:43 3s/step - accuracy: 0.5402 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 15:40 3s/step - ac ...
# Epoch 9/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40:46 7s/step - accuracy: 0.5156 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:54 3s/step - accuracy: 0.5391 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:33 3s/step - accuracy: 0.5295 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:32 3s/step - accuracy: 0.5299 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:28 3s/step - accuracy: 0.5271 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:23 3s/step - accuracy: 0.5221 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:17 3s/step - accuracy: 0.5193 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:13 3s/step - accuracy: 0.5183 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:08 3s/step - accuracy: 0.5175 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:04 3s/step - accuracy: 0.5173 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:00 3s/step - accuracy: 0.5184 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:57 3s/step - accuracy: 0.5199 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:53 3s/step - accuracy: 0.5207 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:50 3s/step - accuracy: 0.5218 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:47 3s/step - accuracy: 0.5225 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:44 3s/step - accuracy: 0.5232 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:41 3s/step - accuracy: 0.5238 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:37 3s/step - accuracy: 0.5244 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:34 3s/step - accuracy: 0.5247 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:31 3s/step - accuracy: 0.5250 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:27 3s/step - accuracy: 0.5252 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:24 3s/step - accuracy: 0.5254 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:21 3s/step - accuracy: 0.5255 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:17 3s/step - accuracy: 0.5257 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:14 3s/step - accuracy: 0.5258 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:11 3s/step - accuracy: 0.5259 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:07 3s/step - accuracy: 0.5261 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:04 3s/step - accuracy: 0.5262 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:01 3s/step - accuracy: 0.5263 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:58 3s/step - accuracy: 0.5264 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:56 3s/step - accuracy: 0.5266 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:53 3s/step - accuracy: 0.5269 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:50 3s/step - accuracy: 0.5271 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:47 3s/step - accuracy: 0.5274 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:44 3s/step - accuracy: 0.5276 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:41 3s/step - accuracy: 0.5278 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:38 3s/step - accuracy: 0.5280 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:35 3s/step - accuracy: 0.5282 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:32 3s/step - accuracy: 0.5283 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:30 3s/step - accuracy: 0.5285 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:27 3s/step - accuracy: 0.5286 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:24 3s/step - accuracy: 0.5288 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:21 3s/step - accuracy: 0.5290 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:18 3s/step - accuracy: 0.5293 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:14 3s/step - accuracy: 0.5295 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:11 3s/step - accuracy: 0.5298 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:08 3s/step - accuracy: 0.5300 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:04 3s/step - accuracy: 0.5302 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:01 3s/step - accuracy: 0.5304 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:57 3s/step - accuracy: 0.5306 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:54 3s/step - accuracy: 0.5308 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:50 3s/step - accuracy: 0.5309 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:47 3s/step - accuracy: 0.5311 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:43 3s/step - accuracy: 0.5312 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:40 3s/step - accuracy: 0.5314 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:37 3s/step - accuracy: 0.5315 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:33 3s/step - accuracy: 0.5316 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:30 3s/step - accuracy: 0.5318 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:27 3s/step - accuracy: 0.5319 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:23 3s/step - ac ...
# Epoch 10/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 37:12 6s/step - accuracy: 0.5938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:45 3s/step - accuracy: 0.5820 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:53 3s/step - accuracy: 0.5773 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:43 3s/step - accuracy: 0.5716 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:37 3s/step - accuracy: 0.5692 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:32 3s/step - accuracy: 0.5659 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:27 3s/step - accuracy: 0.5629 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:24 3s/step - accuracy: 0.5596 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:20 3s/step - accuracy: 0.5580 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:17 3s/step - accuracy: 0.5569 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:14 3s/step - accuracy: 0.5563 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:10 3s/step - accuracy: 0.5553 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:06 3s/step - accuracy: 0.5541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:01 3s/step - accuracy: 0.5529 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:57 3s/step - accuracy: 0.5517 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:54 3s/step - accuracy: 0.5506 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:51 3s/step - accuracy: 0.5497 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:47 3s/step - accuracy: 0.5491 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:44 3s/step - accuracy: 0.5486 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:41 3s/step - accuracy: 0.5482 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:37 3s/step - accuracy: 0.5477 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:33 3s/step - accuracy: 0.5472 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:30 3s/step - accuracy: 0.5469 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:27 3s/step - accuracy: 0.5467 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:23 3s/step - accuracy: 0.5465 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:20 3s/step - accuracy: 0.5463 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:16 3s/step - accuracy: 0.5461 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:13 3s/step - accuracy: 0.5460 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:10 3s/step - accuracy: 0.5459 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:06 3s/step - accuracy: 0.5460 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:03 3s/step - accuracy: 0.5460 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:00 3s/step - accuracy: 0.5460 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:56 3s/step - accuracy: 0.5460 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:53 3s/step - accuracy: 0.5459 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:50 3s/step - accuracy: 0.5458 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:46 3s/step - accuracy: 0.5456 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:43 3s/step - accuracy: 0.5455 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:39 3s/step - accuracy: 0.5455 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:36 3s/step - accuracy: 0.5454 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:33 3s/step - accuracy: 0.5453 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:29 3s/step - accuracy: 0.5451 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:26 3s/step - accuracy: 0.5449 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:23 3s/step - accuracy: 0.5447 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:19 3s/step - accuracy: 0.5446 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:16 3s/step - accuracy: 0.5445 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:13 3s/step - accuracy: 0.5444 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:09 3s/step - accuracy: 0.5442 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:06 3s/step - accuracy: 0.5441 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:03 3s/step - accuracy: 0.5440 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:59 3s/step - accuracy: 0.5440 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:56 3s/step - accuracy: 0.5439 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:53 3s/step - accuracy: 0.5438 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:50 3s/step - accuracy: 0.5438 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:47 3s/step - accuracy: 0.5437 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:43 3s/step - accuracy: 0.5437 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:40 3s/step - accuracy: 0.5436 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:37 3s/step - accuracy: 0.5436 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:33 3s/step - accuracy: 0.5436 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:30 3s/step - accuracy: 0.5436 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:27 3s/step - ac ...
# Epoch 11/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40:31 7s/step - accuracy: 0.5469 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:39 3s/step - accuracy: 0.5547 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:34 3s/step - accuracy: 0.5434 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:27 3s/step - accuracy: 0.5384 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:21 3s/step - accuracy: 0.5420 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:17 3s/step - accuracy: 0.5450 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:14 3s/step - accuracy: 0.5475 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:10 3s/step - accuracy: 0.5493 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:07 3s/step - accuracy: 0.5518 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:03 3s/step - accuracy: 0.5541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:00 3s/step - accuracy: 0.5564 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:56 3s/step - accuracy: 0.5589 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:52 3s/step - accuracy: 0.5608 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:49 3s/step - accuracy: 0.5620 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:46 3s/step - accuracy: 0.5628 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:43 3s/step - accuracy: 0.5637 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:40 3s/step - accuracy: 0.5644 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:37 3s/step - accuracy: 0.5648 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:34 3s/step - accuracy: 0.5652 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:31 3s/step - accuracy: 0.5657 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:27 3s/step - accuracy: 0.5660 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:24 3s/step - accuracy: 0.5664 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:21 3s/step - accuracy: 0.5667 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:18 3s/step - accuracy: 0.5671 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:14 3s/step - accuracy: 0.5675 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:11 3s/step - accuracy: 0.5678 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:07 3s/step - accuracy: 0.5679 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:04 3s/step - accuracy: 0.5680 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:01 3s/step - accuracy: 0.5682 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:57 3s/step - accuracy: 0.5684 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:54 3s/step - accuracy: 0.5686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:51 3s/step - accuracy: 0.5689 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:48 3s/step - accuracy: 0.5690 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:44 3s/step - accuracy: 0.5691 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:41 3s/step - accuracy: 0.5692 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:38 3s/step - accuracy: 0.5692 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:35 3s/step - accuracy: 0.5693 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:32 3s/step - accuracy: 0.5693 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:28 3s/step - accuracy: 0.5691 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:25 3s/step - accuracy: 0.5690 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:22 3s/step - accuracy: 0.5689 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:19 3s/step - accuracy: 0.5688 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:15 3s/step - accuracy: 0.5688 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:12 3s/step - accuracy: 0.5687 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:09 3s/step - accuracy: 0.5687 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:06 3s/step - accuracy: 0.5686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:02 3s/step - accuracy: 0.5686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:59 3s/step - accuracy: 0.5686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:56 3s/step - accuracy: 0.5686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:53 3s/step - accuracy: 0.5686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:50 3s/step - accuracy: 0.5686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:46 3s/step - accuracy: 0.5686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:43 3s/step - accuracy: 0.5686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:41 3s/step - accuracy: 0.5686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:39 3s/step - accuracy: 0.5687 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:38 3s/step - accuracy: 0.5687 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:36 3s/step - accuracy: 0.5687 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:35 3s/step - accuracy: 0.5687 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:33 3s/step - accuracy: 0.5688 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:30 3s/step - ac ...
# Epoch 12/100
# ...
# Epoch 98/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 39:35 7s/step - accuracy: 0.8594 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:45 3s/step - accuracy: 0.8828 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:32 3s/step - accuracy: 0.8802 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:21 3s/step - accuracy: 0.8770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:15 3s/step - accuracy: 0.8753 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:13 3s/step - accuracy: 0.8731 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:13 3s/step - accuracy: 0.8721 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:14 3s/step - accuracy: 0.8722 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:15 3s/step - accuracy: 0.8725 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:19 3s/step - accuracy: 0.8728 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:21 3s/step - accuracy: 0.8732 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:24 3s/step - accuracy: 0.8736 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:23 3s/step - accuracy: 0.8741 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:19 3s/step - accuracy: 0.8744 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:12 3s/step - accuracy: 0.8743 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:07 3s/step - accuracy: 0.8745 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:03 3s/step - accuracy: 0.8746 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:58 3s/step - accuracy: 0.8748 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:54 3s/step - accuracy: 0.8749 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:52 3s/step - accuracy: 0.8751 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:49 3s/step - accuracy: 0.8754 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:45 3s/step - accuracy: 0.8756 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:41 3s/step - accuracy: 0.8757 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:37 3s/step - accuracy: 0.8757 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:31 3s/step - accuracy: 0.8758 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:27 3s/step - accuracy: 0.8757 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:22 3s/step - accuracy: 0.8756 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:19 3s/step - accuracy: 0.8756 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:14 3s/step - accuracy: 0.8756 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:10 3s/step - accuracy: 0.8754 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:06 3s/step - accuracy: 0.8753 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:03 3s/step - accuracy: 0.8752 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:58 3s/step - accuracy: 0.8750 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:54 3s/step - accuracy: 0.8749 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:50 3s/step - accuracy: 0.8746 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:47 3s/step - accuracy: 0.8744 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:43 3s/step - accuracy: 0.8740 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:39 3s/step - accuracy: 0.8738 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:36 3s/step - accuracy: 0.8735 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:32 3s/step - accuracy: 0.8732 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:28 3s/step - accuracy: 0.8729 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:26 3s/step - accuracy: 0.8727 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:22 3s/step - accuracy: 0.8724 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:19 3s/step - accuracy: 0.8722 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:15 3s/step - accuracy: 0.8720 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:11 3s/step - accuracy: 0.8718 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:08 3s/step - accuracy: 0.8716 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:05 3s/step - accuracy: 0.8714 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:01 3s/step - accuracy: 0.8712 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:57 3s/step - accuracy: 0.8711 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:54 3s/step - accuracy: 0.8709 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:50 3s/step - accuracy: 0.8707 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:47 3s/step - accuracy: 0.8705 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:43 3s/step - accuracy: 0.8703 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:40 3s/step - accuracy: 0.8701 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:36 3s/step - accuracy: 0.8700 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:33 3s/step - accuracy: 0.8699 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:29 3s/step - accuracy: 0.8697 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:26 3s/step - accuracy: 0.8696 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:22 3s/step - ac ...
# Epoch 99/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 38:54 7s/step - accuracy: 0.9375 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:39 3s/step - accuracy: 0.9297 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:27 3s/step - accuracy: 0.9253 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:28 3s/step - accuracy: 0.9245 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:33 3s/step - accuracy: 0.9208 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:41 3s/step - accuracy: 0.9180 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:48 3s/step - accuracy: 0.9169 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:46 3s/step - accuracy: 0.9161 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:46 3s/step - accuracy: 0.9144 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:47 3s/step - accuracy: 0.9131 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:46 3s/step - accuracy: 0.9124 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:46 3s/step - accuracy: 0.9111 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:47 3s/step - accuracy: 0.9102 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:45 3s/step - accuracy: 0.9092 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:43 3s/step - accuracy: 0.9082 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:38 3s/step - accuracy: 0.9075 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:39 3s/step - accuracy: 0.9069 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:37 3s/step - accuracy: 0.9062 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:35 3s/step - accuracy: 0.9055 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:30 3s/step - accuracy: 0.9049 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:24 3s/step - accuracy: 0.9044 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:17 3s/step - accuracy: 0.9039 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:12 3s/step - accuracy: 0.9033 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:06 3s/step - accuracy: 0.9028 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 19:02 3s/step - accuracy: 0.9023 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:58 3s/step - accuracy: 0.9018 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:53 3s/step - accuracy: 0.9013 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:48 3s/step - accuracy: 0.9008 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:43 3s/step - accuracy: 0.9005 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:41 3s/step - accuracy: 0.9001 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:36 3s/step - accuracy: 0.8996 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:31 3s/step - accuracy: 0.8991 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:27 3s/step - accuracy: 0.8987 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:23 3s/step - accuracy: 0.8982 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:18 3s/step - accuracy: 0.8978 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:15 3s/step - accuracy: 0.8975 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:11 3s/step - accuracy: 0.8971 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:07 3s/step - accuracy: 0.8967 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 18:04 3s/step - accuracy: 0.8963 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:59 3s/step - accuracy: 0.8959 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:55 3s/step - accuracy: 0.8956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:51 3s/step - accuracy: 0.8952 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:48 3s/step - accuracy: 0.8949 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:47 3s/step - accuracy: 0.8946 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:45 3s/step - accuracy: 0.8943 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:43 3s/step - accuracy: 0.8941 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:41 3s/step - accuracy: 0.8938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:39 3s/step - accuracy: 0.8935 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:37 3s/step - accuracy: 0.8933 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:34 3s/step - accuracy: 0.8930 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:31 3s/step - accuracy: 0.8928 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:28 3s/step - accuracy: 0.8925 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:25 3s/step - accuracy: 0.8922 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:22 3s/step - accuracy: 0.8920 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:19 3s/step - accuracy: 0.8918 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:16 3s/step - accuracy: 0.8916 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:11 3s/step - accuracy: 0.8914 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:07 3s/step - accuracy: 0.8912 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 17:03 3s/step - accuracy: 0.8911 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 16:59 3s/step - ac ...
# Epoch 100/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 48:59 8s/step - accuracy: 0.8906 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:18 4s/step - accuracy: 0.8945 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:26 4s/step - accuracy: 0.8932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:06 4s/step - accuracy: 0.8955 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:57 4s/step - accuracy: 0.8964 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:50 4s/step - accuracy: 0.8963 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:44 4s/step - accuracy: 0.8958 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:49 4s/step - accuracy: 0.8959 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:48 4s/step - accuracy: 0.8961 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:42 4s/step - accuracy: 0.8960 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:36 4s/step - accuracy: 0.8956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:31 4s/step - accuracy: 0.8954 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:30 4s/step - accuracy: 0.8953 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:34 4s/step - accuracy: 0.8948 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:29 4s/step - accuracy: 0.8944 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:27 4s/step - accuracy: 0.8943 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:33 4s/step - accuracy: 0.8939 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:29 4s/step - accuracy: 0.8938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:30 4s/step - accuracy: 0.8938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:37 4s/step - accuracy: 0.8936 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:33 4s/step - accuracy: 0.8935 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:39 4s/step - accuracy: 0.8932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:43 4s/step - accuracy: 0.8930 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:51 4s/step - accuracy: 0.8927 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:55 4s/step - accuracy: 0.8924 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:52 4s/step - accuracy: 0.8922 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:51 4s/step - accuracy: 0.8918 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:47 4s/step - accuracy: 0.8914 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:42 4s/step - accuracy: 0.8911 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:40 4s/step - accuracy: 0.8909 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:36 4s/step - accuracy: 0.8906 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:30 4s/step - accuracy: 0.8904 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:23 4s/step - accuracy: 0.8901 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:17 4s/step - accuracy: 0.8899 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:10 4s/step - accuracy: 0.8896 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:05 4s/step - accuracy: 0.8893 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:01 4s/step - accuracy: 0.8891 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:55 4s/step - accuracy: 0.8888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:50 4s/step - accuracy: 0.8885 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:43 4s/step - accuracy: 0.8883 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:38 4s/step - accuracy: 0.8880 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:36 4s/step - accuracy: 0.8878 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:36 4s/step - accuracy: 0.8877 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:30 4s/step - accuracy: 0.8875 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:26 4s/step - accuracy: 0.8873 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:21 4s/step - accuracy: 0.8871 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:19 4s/step - accuracy: 0.8869 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:13 4s/step - accuracy: 0.8867 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:08 4s/step - accuracy: 0.8866 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:04 4s/step - accuracy: 0.8865 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 21:00 4s/step - accuracy: 0.8863 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:54 4s/step - accuracy: 0.8862 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:49 4s/step - accuracy: 0.8860 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:44 4s/step - accuracy: 0.8859 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:39 4s/step - accuracy: 0.8857 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:34 4s/step - accuracy: 0.8856 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:29 4s/step - accuracy: 0.8855 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:26 4s/step - accuracy: 0.8853 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:23 4s/step - accuracy: 0.8852 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 20:18 4s/step - ac ...

# %%
student_model.save('Trained Model/LEC_model_student.keras')
