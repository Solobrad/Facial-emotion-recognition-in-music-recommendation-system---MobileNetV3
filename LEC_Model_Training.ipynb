# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import gc
import h5py
import wandb
import sys
from dotenv import load_dotenv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras.applications import MobileNetV2, MobileNetV3Small, MobileNetV3Large
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import KLDivergence

# %%
load_dotenv()  # Load environment variables from .env file
api_key = os.getenv("WANDB_API_KEY")

wandb.login(key=api_key)  # Login with the API key
wandb.init(project="LEC_Model", entity=os.getenv("WANDB_USERNAME"))
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: nicholas66. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.1
# Run data is saved locally in <code>n:\Thesis 2\Code\wandb\run-20240923_112037-sh5ojmj2</code>
# Syncing run <strong><a href='https://wandb.ai/nicholas66/LEC_Model/runs/sh5ojmj2' target="_blank">easy-breeze-23</a></strong> to <a href='https://wandb.ai/nicholas66/LEC_Model' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nicholas66/LEC_Model' target="_blank">https://wandb.ai/nicholas66/LEC_Model</a>
#  View run at <a href='https://wandb.ai/nicholas66/LEC_Model/runs/sh5ojmj2' target="_blank">https://wandb.ai/nicholas66/LEC_Model/runs/sh5ojmj2</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/nicholas66/LEC_Model/runs/sh5ojmj2?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def load_data(hdf5_file, dataset_name_images, dataset_name_labels):
    with h5py.File(hdf5_file, 'r') as hf:
        data = np.array(hf[dataset_name_images])
        labels = np.array(hf[dataset_name_labels])
    return data, labels

# Load data
data, labels = load_data('output files/combined_images_labels.h5', 'combined_images', 'combined_labels')

# Print shapes to verify
print(f"Data shape: {data.shape}")
print(f"Labels shape: {labels.shape}")

# Ensure that data and labels are not empty
assert len(data) > 0, "Data is empty."
assert len(labels) > 0, "Labels are empty."

# Split data
X_train, X_val, y_train, y_val = train_test_split(
    data, 
    labels, 
    test_size=0.2, 
    stratify=labels
)

# Print shapes of the split data
print(f"Training data shape: {X_train.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Validation data shape: {X_val.shape}")
print(f"Validation labels shape: {y_val.shape}")
# Out:
# Data shape: (40980, 224, 224, 3)
# Labels shape: (40980,)
# Training data shape: (32784, 224, 224, 3)
# Training labels shape: (32784,)
# Validation data shape: (8196, 224, 224, 3)
# Validation labels shape: (8196,)

# %%
# Define the data augmentation transformations
train_datagen = ImageDataGenerator(
    rotation_range=20,         # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,     # Randomly shift images horizontally by up to 20% of the width
    height_shift_range=0.2,    # Randomly shift images vertically by up to 20% of the height
    shear_range=0.2,           # Randomly apply shearing transformation
    zoom_range=0.2,            # Randomly zoom images by up to 20%
    horizontal_flip=True,      # Randomly flip images horizontally
    fill_mode='nearest'        # Strategy for filling in newly created pixels
)

# Create data generator for training data
train_generator = train_datagen.flow(
    X_train,   # Training images
    y_train,   # Training labels
    batch_size=84  # Batch size for training
)

validation_datagen = ImageDataGenerator()

# Create data generator for validation data
validation_generator = validation_datagen.flow(
    X_val,  # Validation images
    y_val,  # Validation labels
    batch_size=84   # Batch size for validation
)

# %% [markdown]
# # Teacher Model

# %%
def create_teacher_model():
    teacher_model = EfficientNetB4(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    teacher_model.trainable = False  # We don't want to train the teacher
    model = Sequential([
        teacher_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(7, activation='softmax')  # 7 emotion classes
    ])
    return model

# %% [markdown]
# # LEC Model (Student)

# %%
def create_student_model():
    # Load MobileNetV3 as base model
    base_model = MobileNetV3Small(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
    # Freeze initial layers
    for layer in base_model.layers[:5]:  # Adjust the range as needed
        layer.trainable = False
    
    # Build the custom top layers
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        Dense(7, activation='softmax')  # Assuming 7 emotion classes
    ])

    return model

# %%
teacher_model = create_teacher_model()
student_model = create_student_model()

# Custom callback for WandB
class WandBCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        wandb.log({
            "Epoch Loss": logs.get("loss"),
            "Epoch Accuracy": logs.get("accuracy"),
            "Val Loss": logs.get("val_loss"),
            "Val Accuracy": logs.get("val_accuracy"),
            "epoch": epoch + 1 
        })

        

# Compile the student model
# student_model.compile(
#     optimizer=Adam(learning_rate=1e-4),
#     loss=lambda y_true, y_pred: knowledge_distillation_loss(y_true, y_pred, teacher_model.predict(train_generator[0][0])),  
#     metrics=['accuracy']
# )

# Define the knowledge distillation loss function
def knowledge_distillation_loss(y_true, y_pred, teacher_logits, T=3, alpha=0.5):
    
    # Hard loss (real labels)
    hard_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    # Soft loss (teacher predictions)
    soft_loss = KLDivergence()(
        tf.nn.softmax(teacher_logits / T),
        tf.nn.softmax(y_pred / T)
    )
    # Combined loss
    return alpha * hard_loss + (1 - alpha) * soft_loss

# %%
# Custom training step for batch-wise teacher logits
class CustomDistillationModel(tf.keras.Model):
    def __init__(self, student, teacher):
        super(CustomDistillationModel, self).__init__()
        self.student = student
        self.teacher = teacher

    def call(self, inputs, training=False):
        return self.student(inputs, training=training)

    def train_step(self, data):
        x, y_true = data
        
        # Get teacher predictions for the current batch
        teacher_logits = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Student predictions
            y_pred = self.student(x, training=True)
            # Compute the KD loss
            loss = knowledge_distillation_loss(y_true, y_pred, teacher_logits)

        # Compute gradients and update weights
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update metrics (accuracy)
        self.compiled_metrics.update_state(y_true, y_pred)

        return {m.name: m.result() for m in self.metrics}

# Create the custom KD model
distilled_model = CustomDistillationModel(student_model, teacher_model)

# Compile the student model (no need to modify the WandB callback)
distilled_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model as before

# %%
distilled_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=50,
    callbacks=[WandBCallback()],
    verbose=1
)
# Out:
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3:24:01 31s/step - accuracy: 0.1310 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 29:03 4s/step - accuracy: 0.1548 - loss: 0.1429  ━━━━━━━━━━━━━━━━━━━━ 30:44 5s/step - accuracy: 0.1693 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:14 5s/step - accuracy: 0.1850 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:16 5s/step - accuracy: 0.1942 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:02 5s/step - accuracy: 0.1989 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:40 5s/step - accuracy: 0.2016 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:19 5s/step - accuracy: 0.2046 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:06 5s/step - accuracy: 0.2081 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:08 5s/step - accuracy: 0.2112 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:17 5s/step - accuracy: 0.2142 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:06 5s/step - accuracy: 0.2175 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:52 5s/step - accuracy: 0.2200 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:41 5s/step - accuracy: 0.2219 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:28 5s/step - accuracy: 0.2237 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:16 5s/step - accuracy: 0.2248 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:08 5s/step - accuracy: 0.2259 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:57 4s/step - accuracy: 0.2270 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:45 4s/step - accuracy: 0.2278 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:34 4s/step - accuracy: 0.2285 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:24 4s/step - accuracy: 0.2292 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:14 4s/step - accuracy: 0.2298 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:08 4s/step - accuracy: 0.2304 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:04 4s/step - accuracy: 0.2309 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:00 4s/step - accuracy: 0.2313 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:52 4s/step - accuracy: 0.2317 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:44 4s/step - accuracy: 0.2322 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:38 4s/step - accuracy: 0.2325 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:31 4s/step - accuracy: 0.2328 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:25 4s/step - accuracy: 0.2331 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:18 4s/step - accuracy: 0.2335 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:12 4s/step - accuracy: 0.2338 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:06 4s/step - accuracy: 0.2340 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:59 4s/step - accuracy: 0.2343 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:53 4s/step - accuracy: 0.2346 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:47 4s/step - accuracy: 0.2348 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:41 4s/step - accuracy: 0.2350 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:35 4s/step - accuracy: 0.2352 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:33 4s/step - accuracy: 0.2354 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:32 4s/step - accuracy: 0.2355 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:28 4s/step - accuracy: 0.2356 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:24 4s/step - accuracy: 0.2358 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:20 4s/step - accuracy: 0.2359 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:16 4s/step - accuracy: 0.2360 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:12 4s/step - accuracy: 0.2362 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:08 4s/step - accuracy: 0.2363 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:06 4s/step - accuracy: 0.2365 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:01 4s/step - accuracy: 0.2366 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:55 4s/step - accuracy: 0.2368 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:49 4s/step - accuracy: 0.2370 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:43 4s/step - accuracy: 0.2371 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:37 4s/step - accuracy: 0.2372 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:31 4s/step - accuracy: 0.2374 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:27 4s/step - accuracy: 0.2375 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:23 4s/step - accuracy: 0.2376 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:17 4s/step - accuracy: 0.2377 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:12 4s/step - accuracy: 0.2378 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:06 4s/step - accuracy: 0.2379 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:01 4s/step - accuracy: 0.2380 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:55 4s/st ...
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 59:24 9s/step - accuracy: 0.2500 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:08 4s/step - accuracy: 0.2470 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:48 4s/step - accuracy: 0.2480 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:43 4s/step - accuracy: 0.2515 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:34 4s/step - accuracy: 0.2536 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:26 4s/step - accuracy: 0.2553 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:17 4s/step - accuracy: 0.2548 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:12 4s/step - accuracy: 0.2538 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:12 4s/step - accuracy: 0.2525 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:09 4s/step - accuracy: 0.2508 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:07 4s/step - accuracy: 0.2494 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:00 4s/step - accuracy: 0.2479 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:54 4s/step - accuracy: 0.2472 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:50 4s/step - accuracy: 0.2470 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:44 4s/step - accuracy: 0.2468 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:39 4s/step - accuracy: 0.2468 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:35 4s/step - accuracy: 0.2469 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:30 4s/step - accuracy: 0.2469 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:25 4s/step - accuracy: 0.2468 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:21 4s/step - accuracy: 0.2469 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:17 4s/step - accuracy: 0.2470 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:13 4s/step - accuracy: 0.2470 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:10 4s/step - accuracy: 0.2469 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:05 4s/step - accuracy: 0.2469 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:01 4s/step - accuracy: 0.2472 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:56 4s/step - accuracy: 0.2473 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:52 4s/step - accuracy: 0.2475 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:47 4s/step - accuracy: 0.2476 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:43 4s/step - accuracy: 0.2477 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:39 4s/step - accuracy: 0.2477 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:34 4s/step - accuracy: 0.2476 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:30 4s/step - accuracy: 0.2475 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:25 4s/step - accuracy: 0.2475 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:21 4s/step - accuracy: 0.2474 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:16 4s/step - accuracy: 0.2474 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:12 4s/step - accuracy: 0.2474 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:07 4s/step - accuracy: 0.2475 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:03 4s/step - accuracy: 0.2476 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:58 4s/step - accuracy: 0.2476 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:54 4s/step - accuracy: 0.2476 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:52 4s/step - accuracy: 0.2477 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:48 4s/step - accuracy: 0.2477 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:45 4s/step - accuracy: 0.2477 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:40 4s/step - accuracy: 0.2478 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:36 4s/step - accuracy: 0.2479 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:32 4s/step - accuracy: 0.2479 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:27 4s/step - accuracy: 0.2480 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:23 4s/step - accuracy: 0.2481 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:19 4s/step - accuracy: 0.2482 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:15 4s/step - accuracy: 0.2482 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:11 4s/step - accuracy: 0.2482 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:07 4s/step - accuracy: 0.2483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:02 4s/step - accuracy: 0.2483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:59 4s/step - accuracy: 0.2483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:54 4s/step - accuracy: 0.2483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:50 4s/step - accuracy: 0.2483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:46 4s/step - accuracy: 0.2483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:42 4s/step - accuracy: 0.2483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:37 4s/step - accuracy: 0.2484 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:33 4s/step - ac ...
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 56:21 9s/step - accuracy: 0.2262 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:20 4s/step - accuracy: 0.2440 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:15 4s/step - accuracy: 0.2526 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:20 4s/step - accuracy: 0.2542 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:16 4s/step - accuracy: 0.2558 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:11 4s/step - accuracy: 0.2584 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:04 4s/step - accuracy: 0.2592 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:06 4s/step - accuracy: 0.2595 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:03 4s/step - accuracy: 0.2596 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:57 4s/step - accuracy: 0.2597 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:52 4s/step - accuracy: 0.2599 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:47 4s/step - accuracy: 0.2600 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:43 4s/step - accuracy: 0.2599 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:39 4s/step - accuracy: 0.2599 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:41 4s/step - accuracy: 0.2605 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:36 4s/step - accuracy: 0.2610 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:31 4s/step - accuracy: 0.2616 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:27 4s/step - accuracy: 0.2623 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:24 4s/step - accuracy: 0.2632 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:21 4s/step - accuracy: 0.2637 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:18 4s/step - accuracy: 0.2641 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:15 4s/step - accuracy: 0.2645 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:12 4s/step - accuracy: 0.2649 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:08 4s/step - accuracy: 0.2653 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:05 4s/step - accuracy: 0.2657 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:03 4s/step - accuracy: 0.2662 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:01 4s/step - accuracy: 0.2665 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:00 4s/step - accuracy: 0.2667 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:56 4s/step - accuracy: 0.2669 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:52 4s/step - accuracy: 0.2671 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:47 4s/step - accuracy: 0.2671 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:42 4s/step - accuracy: 0.2671 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:37 4s/step - accuracy: 0.2671 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:33 4s/step - accuracy: 0.2670 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:28 4s/step - accuracy: 0.2669 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:25 4s/step - accuracy: 0.2669 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:21 4s/step - accuracy: 0.2669 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:17 4s/step - accuracy: 0.2668 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:13 4s/step - accuracy: 0.2667 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:10 4s/step - accuracy: 0.2668 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:05 4s/step - accuracy: 0.2668 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:01 4s/step - accuracy: 0.2668 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:56 4s/step - accuracy: 0.2667 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:52 4s/step - accuracy: 0.2667 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:47 4s/step - accuracy: 0.2667 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:43 4s/step - accuracy: 0.2667 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:41 4s/step - accuracy: 0.2667 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:36 4s/step - accuracy: 0.2668 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:33 4s/step - accuracy: 0.2669 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:29 4s/step - accuracy: 0.2670 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:24 4s/step - accuracy: 0.2671 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:20 4s/step - accuracy: 0.2672 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:16 4s/step - accuracy: 0.2673 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:11 4s/step - accuracy: 0.2674 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:07 4s/step - accuracy: 0.2675 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:03 4s/step - accuracy: 0.2676 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:58 4s/step - accuracy: 0.2677 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:54 4s/step - accuracy: 0.2678 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:50 4s/step - accuracy: 0.2679 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:46 4s/step - ac ...
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 57:13 9s/step - accuracy: 0.3571 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:39 4s/step - accuracy: 0.3244 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:31 4s/step - accuracy: 0.3142 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:30 4s/step - accuracy: 0.3063 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:25 4s/step - accuracy: 0.3031 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:21 4s/step - accuracy: 0.3006 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:15 4s/step - accuracy: 0.2960 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:18 4s/step - accuracy: 0.2934 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:13 4s/step - accuracy: 0.2927 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:08 4s/step - accuracy: 0.2917 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:03 4s/step - accuracy: 0.2908 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:59 4s/step - accuracy: 0.2897 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:55 4s/step - accuracy: 0.2890 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:56 4s/step - accuracy: 0.2884 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:02 4s/step - accuracy: 0.2880 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:58 4s/step - accuracy: 0.2875 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:54 4s/step - accuracy: 0.2871 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:50 4s/step - accuracy: 0.2864 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:45 4s/step - accuracy: 0.2858 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:42 4s/step - accuracy: 0.2852 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:36 4s/step - accuracy: 0.2848 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:31 4s/step - accuracy: 0.2845 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:27 4s/step - accuracy: 0.2841 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:22 4s/step - accuracy: 0.2839 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:16 4s/step - accuracy: 0.2836 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:13 4s/step - accuracy: 0.2834 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:08 4s/step - accuracy: 0.2833 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:06 4s/step - accuracy: 0.2832 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:00 4s/step - accuracy: 0.2830 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:57 4s/step - accuracy: 0.2829 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:52 4s/step - accuracy: 0.2827 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:47 4s/step - accuracy: 0.2826 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:42 4s/step - accuracy: 0.2824 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:38 4s/step - accuracy: 0.2823 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:33 4s/step - accuracy: 0.2822 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:28 4s/step - accuracy: 0.2821 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:25 4s/step - accuracy: 0.2820 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:20 4s/step - accuracy: 0.2821 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:16 4s/step - accuracy: 0.2821 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:12 4s/step - accuracy: 0.2821 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:07 4s/step - accuracy: 0.2821 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:02 4s/step - accuracy: 0.2821 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:57 4s/step - accuracy: 0.2822 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:54 4s/step - accuracy: 0.2822 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:50 4s/step - accuracy: 0.2823 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:46 4s/step - accuracy: 0.2823 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:41 4s/step - accuracy: 0.2824 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:37 4s/step - accuracy: 0.2825 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:32 4s/step - accuracy: 0.2826 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:28 4s/step - accuracy: 0.2827 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:24 4s/step - accuracy: 0.2828 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:19 4s/step - accuracy: 0.2828 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:16 4s/step - accuracy: 0.2829 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:11 4s/step - accuracy: 0.2830 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:07 4s/step - accuracy: 0.2831 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:03 4s/step - accuracy: 0.2831 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:58 4s/step - accuracy: 0.2831 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:54 4s/step - accuracy: 0.2832 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:51 4s/step - accuracy: 0.2832 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:47 4s/step - ac ...
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 59:04 9s/step - accuracy: 0.2976 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:19 4s/step - accuracy: 0.2827 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:06 4s/step - accuracy: 0.2837 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:09 4s/step - accuracy: 0.2812 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:04 4s/step - accuracy: 0.2802 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:02 4s/step - accuracy: 0.2772 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:19 4s/step - accuracy: 0.2745 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:12 4s/step - accuracy: 0.2731 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:06 4s/step - accuracy: 0.2714 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:06 4s/step - accuracy: 0.2706 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:06 4s/step - accuracy: 0.2706 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:57 4s/step - accuracy: 0.2700 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:50 4s/step - accuracy: 0.2697 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:42 4s/step - accuracy: 0.2699 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:36 4s/step - accuracy: 0.2696 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:30 4s/step - accuracy: 0.2697 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:24 4s/step - accuracy: 0.2697 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:19 4s/step - accuracy: 0.2695 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:12 4s/step - accuracy: 0.2695 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:07 4s/step - accuracy: 0.2695 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:02 4s/step - accuracy: 0.2696 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:56 4s/step - accuracy: 0.2698 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:51 4s/step - accuracy: 0.2701 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:51 4s/step - accuracy: 0.2704 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:49 4s/step - accuracy: 0.2706 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:44 4s/step - accuracy: 0.2708 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:39 4s/step - accuracy: 0.2710 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:34 4s/step - accuracy: 0.2712 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:29 4s/step - accuracy: 0.2715 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:25 4s/step - accuracy: 0.2718 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:21 4s/step - accuracy: 0.2719 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:17 4s/step - accuracy: 0.2721 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:12 4s/step - accuracy: 0.2723 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:11 4s/step - accuracy: 0.2724 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:12 4s/step - accuracy: 0.2725 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:08 4s/step - accuracy: 0.2725 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:07 4s/step - accuracy: 0.2726 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:02 4s/step - accuracy: 0.2725 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:58 4s/step - accuracy: 0.2725 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:54 4s/step - accuracy: 0.2725 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:52 4s/step - accuracy: 0.2726 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:51 4s/step - accuracy: 0.2727 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:46 4s/step - accuracy: 0.2727 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:40 4s/step - accuracy: 0.2728 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:39 4s/step - accuracy: 0.2729 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:36 4s/step - accuracy: 0.2730 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:39 4s/step - accuracy: 0.2731 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:33 4s/step - accuracy: 0.2732 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:26 4s/step - accuracy: 0.2733 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:20 4s/step - accuracy: 0.2733 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:16 4s/step - accuracy: 0.2734 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:13 4s/step - accuracy: 0.2735 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:08 4s/step - accuracy: 0.2735 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:04 4s/step - accuracy: 0.2736 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:00 4s/step - accuracy: 0.2737 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:54 4s/step - accuracy: 0.2738 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:49 4s/step - accuracy: 0.2739 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:45 4s/step - accuracy: 0.2740 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:40 4s/step - accuracy: 0.2741 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:35 4s/step - ac ...
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 57:31 9s/step - accuracy: 0.2262 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:33 4s/step - accuracy: 0.2530 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:38 4s/step - accuracy: 0.2599 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:41 4s/step - accuracy: 0.2686 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:38 4s/step - accuracy: 0.2744 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:34 4s/step - accuracy: 0.2786 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:28 4s/step - accuracy: 0.2796 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:30 4s/step - accuracy: 0.2795 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:32 4s/step - accuracy: 0.2787 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:26 4s/step - accuracy: 0.2776 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:19 4s/step - accuracy: 0.2769 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:13 4s/step - accuracy: 0.2763 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:09 4s/step - accuracy: 0.2758 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:03 4s/step - accuracy: 0.2757 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:58 4s/step - accuracy: 0.2754 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:53 4s/step - accuracy: 0.2753 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:47 4s/step - accuracy: 0.2752 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:42 4s/step - accuracy: 0.2750 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:37 4s/step - accuracy: 0.2748 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:33 4s/step - accuracy: 0.2749 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:30 4s/step - accuracy: 0.2750 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:25 4s/step - accuracy: 0.2752 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:20 4s/step - accuracy: 0.2754 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:20 4s/step - accuracy: 0.2756 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:15 4s/step - accuracy: 0.2758 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:10 4s/step - accuracy: 0.2759 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:05 4s/step - accuracy: 0.2760 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:00 4s/step - accuracy: 0.2760 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:55 4s/step - accuracy: 0.2761 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:52 4s/step - accuracy: 0.2762 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:47 4s/step - accuracy: 0.2764 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:42 4s/step - accuracy: 0.2766 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:38 4s/step - accuracy: 0.2767 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:34 4s/step - accuracy: 0.2768 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:33 4s/step - accuracy: 0.2770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:28 4s/step - accuracy: 0.2771 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:24 4s/step - accuracy: 0.2771 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:20 4s/step - accuracy: 0.2771 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:15 4s/step - accuracy: 0.2770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:11 4s/step - accuracy: 0.2770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:06 4s/step - accuracy: 0.2770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:02 4s/step - accuracy: 0.2770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:58 4s/step - accuracy: 0.2769 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:55 4s/step - accuracy: 0.2770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:51 4s/step - accuracy: 0.2769 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:47 4s/step - accuracy: 0.2769 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:43 4s/step - accuracy: 0.2769 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:39 4s/step - accuracy: 0.2769 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:35 4s/step - accuracy: 0.2769 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:32 4s/step - accuracy: 0.2769 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:28 4s/step - accuracy: 0.2770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:24 4s/step - accuracy: 0.2770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:20 4s/step - accuracy: 0.2770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:16 4s/step - accuracy: 0.2770 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:12 4s/step - accuracy: 0.2771 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:08 4s/step - accuracy: 0.2771 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:03 4s/step - accuracy: 0.2772 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:59 4s/step - accuracy: 0.2773 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:55 4s/step - accuracy: 0.2773 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:51 4s/step - ac ...
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1:02:11 10s/step - accuracy: 0.3095 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 28:43 4s/step - accuracy: 0.2946 - loss: 0.1429  ━━━━━━━━━━━━━━━━━━━━ 28:58 4s/step - accuracy: 0.2930 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:56 4s/step - accuracy: 0.2934 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:56 4s/step - accuracy: 0.2952 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:01 5s/step - accuracy: 0.2959 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:20 5s/step - accuracy: 0.2957 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:24 5s/step - accuracy: 0.2959 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:23 5s/step - accuracy: 0.2951 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:21 5s/step - accuracy: 0.2946 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:12 5s/step - accuracy: 0.2936 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:11 5s/step - accuracy: 0.2930 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:14 5s/step - accuracy: 0.2929 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:09 5s/step - accuracy: 0.2934 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:04 5s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:00 5s/step - accuracy: 0.2928 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:54 5s/step - accuracy: 0.2925 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:51 5s/step - accuracy: 0.2925 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:51 5s/step - accuracy: 0.2927 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:52 5s/step - accuracy: 0.2928 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:46 5s/step - accuracy: 0.2928 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:37 5s/step - accuracy: 0.2926 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:32 5s/step - accuracy: 0.2925 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:29 5s/step - accuracy: 0.2924 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:21 5s/step - accuracy: 0.2921 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:18 5s/step - accuracy: 0.2917 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:17 5s/step - accuracy: 0.2913 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:12 5s/step - accuracy: 0.2909 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:05 5s/step - accuracy: 0.2905 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:58 5s/step - accuracy: 0.2901 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:52 5s/step - accuracy: 0.2898 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:46 5s/step - accuracy: 0.2893 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:40 5s/step - accuracy: 0.2890 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:34 5s/step - accuracy: 0.2887 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:28 5s/step - accuracy: 0.2884 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:22 5s/step - accuracy: 0.2881 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:19 5s/step - accuracy: 0.2879 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:14 5s/step - accuracy: 0.2876 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:06 5s/step - accuracy: 0.2874 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:00 5s/step - accuracy: 0.2872 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:54 5s/step - accuracy: 0.2869 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:49 5s/step - accuracy: 0.2866 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:45 5s/step - accuracy: 0.2863 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:41 5s/step - accuracy: 0.2860 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:35 5s/step - accuracy: 0.2858 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:31 5s/step - accuracy: 0.2856 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:26 5s/step - accuracy: 0.2854 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:21 5s/step - accuracy: 0.2852 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:17 5s/step - accuracy: 0.2851 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:13 5s/step - accuracy: 0.2850 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:08 5s/step - accuracy: 0.2849 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:04 5s/step - accuracy: 0.2848 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:00 5s/step - accuracy: 0.2847 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:56 5s/step - accuracy: 0.2846 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:52 5s/step - accuracy: 0.2845 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:48 5s/step - accuracy: 0.2844 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:45 5s/step - accuracy: 0.2843 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:40 5s/step - accuracy: 0.2842 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:34 5s/step - accuracy: 0.2841 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:28 5s/st ...
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1:00:07 9s/step - accuracy: 0.3214 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:56 4s/step - accuracy: 0.2946 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 28:09 4s/step - accuracy: 0.2917 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:12 4s/step - accuracy: 0.2902 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:03 4s/step - accuracy: 0.2917 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:52 4s/step - accuracy: 0.2897 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:46 4s/step - accuracy: 0.2884 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:40 4s/step - accuracy: 0.2888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:37 4s/step - accuracy: 0.2889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:35 4s/step - accuracy: 0.2886 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:29 4s/step - accuracy: 0.2884 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:24 4s/step - accuracy: 0.2883 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:18 4s/step - accuracy: 0.2883 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:14 4s/step - accuracy: 0.2886 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:09 4s/step - accuracy: 0.2889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:03 4s/step - accuracy: 0.2891 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:59 4s/step - accuracy: 0.2894 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:56 4s/step - accuracy: 0.2894 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:52 4s/step - accuracy: 0.2893 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:50 4s/step - accuracy: 0.2893 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:47 4s/step - accuracy: 0.2891 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:42 4s/step - accuracy: 0.2888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:38 4s/step - accuracy: 0.2885 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:33 4s/step - accuracy: 0.2882 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:28 4s/step - accuracy: 0.2879 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:24 4s/step - accuracy: 0.2877 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:20 4s/step - accuracy: 0.2874 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:16 4s/step - accuracy: 0.2871 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:12 4s/step - accuracy: 0.2869 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:07 4s/step - accuracy: 0.2867 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:02 4s/step - accuracy: 0.2864 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:57 4s/step - accuracy: 0.2862 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:51 4s/step - accuracy: 0.2860 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:46 4s/step - accuracy: 0.2857 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:41 4s/step - accuracy: 0.2854 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:36 4s/step - accuracy: 0.2852 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:31 4s/step - accuracy: 0.2850 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:26 4s/step - accuracy: 0.2848 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:21 4s/step - accuracy: 0.2847 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:18 4s/step - accuracy: 0.2845 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:13 4s/step - accuracy: 0.2844 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:08 4s/step - accuracy: 0.2842 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:04 4s/step - accuracy: 0.2841 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:59 4s/step - accuracy: 0.2840 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:54 4s/step - accuracy: 0.2839 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:49 4s/step - accuracy: 0.2838 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:45 4s/step - accuracy: 0.2837 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:40 4s/step - accuracy: 0.2836 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:36 4s/step - accuracy: 0.2835 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:31 4s/step - accuracy: 0.2834 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:26 4s/step - accuracy: 0.2833 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:22 4s/step - accuracy: 0.2833 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:18 4s/step - accuracy: 0.2832 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:13 4s/step - accuracy: 0.2832 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:09 4s/step - accuracy: 0.2831 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:04 4s/step - accuracy: 0.2831 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:00 4s/step - accuracy: 0.2831 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:55 4s/step - accuracy: 0.2831 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:51 4s/step - accuracy: 0.2830 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:46 4s/step  ...
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 59:15 9s/step - accuracy: 0.2381 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:58 4s/step - accuracy: 0.2738 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:39 4s/step - accuracy: 0.2751 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:36 4s/step - accuracy: 0.2830 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:31 4s/step - accuracy: 0.2892 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:30 4s/step - accuracy: 0.2939 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:12 4s/step - accuracy: 0.2979 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:03 4s/step - accuracy: 0.3003 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:52 4s/step - accuracy: 0.3032 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:37 4s/step - accuracy: 0.3066 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:33 4s/step - accuracy: 0.3093 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:34 4s/step - accuracy: 0.3111 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:31 4s/step - accuracy: 0.3126 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:24 4s/step - accuracy: 0.3134 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:19 4s/step - accuracy: 0.3142 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:11 4s/step - accuracy: 0.3150 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:10 4s/step - accuracy: 0.3154 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:04 4s/step - accuracy: 0.3156 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:02 4s/step - accuracy: 0.3158 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:00 4s/step - accuracy: 0.3158 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:57 4s/step - accuracy: 0.3157 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:54 4s/step - accuracy: 0.3157 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:50 4s/step - accuracy: 0.3157 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:49 4s/step - accuracy: 0.3157 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:47 4s/step - accuracy: 0.3157 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:41 4s/step - accuracy: 0.3157 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:38 4s/step - accuracy: 0.3156 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:34 4s/step - accuracy: 0.3155 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:29 4s/step - accuracy: 0.3155 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:23 4s/step - accuracy: 0.3155 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:20 4s/step - accuracy: 0.3155 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:16 4s/step - accuracy: 0.3155 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:13 4s/step - accuracy: 0.3153 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:09 4s/step - accuracy: 0.3151 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:05 4s/step - accuracy: 0.3150 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:17 4s/step - accuracy: 0.3148 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:13 4s/step - accuracy: 0.3146 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:09 4s/step - accuracy: 0.3144 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:03 4s/step - accuracy: 0.3142 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:58 4s/step - accuracy: 0.3139 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:53 4s/step - accuracy: 0.3137 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:47 4s/step - accuracy: 0.3135 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:41 4s/step - accuracy: 0.3133 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:36 4s/step - accuracy: 0.3132 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:31 4s/step - accuracy: 0.3130 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:26 4s/step - accuracy: 0.3129 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:21 4s/step - accuracy: 0.3128 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:15 4s/step - accuracy: 0.3127 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:09 4s/step - accuracy: 0.3126 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:03 4s/step - accuracy: 0.3126 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:56 4s/step - accuracy: 0.3125 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:50 4s/step - accuracy: 0.3124 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:44 4s/step - accuracy: 0.3123 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:39 4s/step - accuracy: 0.3123 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:34 4s/step - accuracy: 0.3122 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:28 4s/step - accuracy: 0.3122 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:22 4s/step - accuracy: 0.3121 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:17 4s/step - accuracy: 0.3121 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:10 4s/step - accuracy: 0.3120 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:04 4s/step - ac ...
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 56:02 9s/step - accuracy: 0.3095 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:08 4s/step - accuracy: 0.3155 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:06 4s/step - accuracy: 0.3135 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:03 4s/step - accuracy: 0.3103 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:57 4s/step - accuracy: 0.3092 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:52 4s/step - accuracy: 0.3072 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:47 4s/step - accuracy: 0.3068 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:45 4s/step - accuracy: 0.3061 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:41 4s/step - accuracy: 0.3042 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:36 4s/step - accuracy: 0.3025 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:33 4s/step - accuracy: 0.3009 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:29 4s/step - accuracy: 0.2996 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:25 4s/step - accuracy: 0.2985 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:20 4s/step - accuracy: 0.2976 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:16 4s/step - accuracy: 0.2967 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:11 4s/step - accuracy: 0.2960 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:07 4s/step - accuracy: 0.2956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:03 4s/step - accuracy: 0.2952 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:00 4s/step - accuracy: 0.2950 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:56 4s/step - accuracy: 0.2946 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:52 4s/step - accuracy: 0.2944 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:48 4s/step - accuracy: 0.2941 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:44 4s/step - accuracy: 0.2937 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:41 4s/step - accuracy: 0.2935 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:36 4s/step - accuracy: 0.2933 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:33 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:30 4s/step - accuracy: 0.2931 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:27 4s/step - accuracy: 0.2931 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:23 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:19 4s/step - accuracy: 0.2931 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:15 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:12 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:08 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:04 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:00 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:56 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:52 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:48 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:45 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:41 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:37 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:33 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:29 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:25 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:21 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:17 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:13 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:09 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:05 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:01 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:57 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:53 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:49 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:45 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:41 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:37 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:32 4s/step - accuracy: 0.2932 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:28 4s/step - accuracy: 0.2933 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:24 4s/step - accuracy: 0.2933 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 22:20 4s/step - ac ...
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 57:32 9s/step - accuracy: 0.1905 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:47 5s/step - accuracy: 0.2321 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:39 5s/step - accuracy: 0.2407 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:34 5s/step - accuracy: 0.2498 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:04 5s/step - accuracy: 0.2560 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:52 4s/step - accuracy: 0.2593 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:38 4s/step - accuracy: 0.2631 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:37 4s/step - accuracy: 0.2663 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:27 4s/step - accuracy: 0.2693 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:15 4s/step - accuracy: 0.2721 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:31 4s/step - accuracy: 0.2745 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:36 4s/step - accuracy: 0.2769 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:38 4s/step - accuracy: 0.2788 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:38 4s/step - accuracy: 0.2806 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:37 4s/step - accuracy: 0.2821 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:34 4s/step - accuracy: 0.2835 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:34 4s/step - accuracy: 0.2848 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:29 4s/step - accuracy: 0.2861 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:24 4s/step - accuracy: 0.2874 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:17 4s/step - accuracy: 0.2887 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:10 4s/step - accuracy: 0.2897 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:02 4s/step - accuracy: 0.2907 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:55 4s/step - accuracy: 0.2915 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:49 4s/step - accuracy: 0.2924 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:43 4s/step - accuracy: 0.2931 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:39 4s/step - accuracy: 0.2939 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:38 4s/step - accuracy: 0.2946 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:37 4s/step - accuracy: 0.2951 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:33 4s/step - accuracy: 0.2956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:30 4s/step - accuracy: 0.2960 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:25 4s/step - accuracy: 0.2965 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:23 4s/step - accuracy: 0.2969 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:19 4s/step - accuracy: 0.2973 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:14 4s/step - accuracy: 0.2977 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:08 4s/step - accuracy: 0.2981 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:04 4s/step - accuracy: 0.2984 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:00 4s/step - accuracy: 0.2987 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:57 4s/step - accuracy: 0.2989 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:53 4s/step - accuracy: 0.2991 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:50 4s/step - accuracy: 0.2993 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:44 4s/step - accuracy: 0.2995 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:38 4s/step - accuracy: 0.2997 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:32 4s/step - accuracy: 0.2999 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:27 4s/step - accuracy: 0.3001 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:22 4s/step - accuracy: 0.3003 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:16 4s/step - accuracy: 0.3006 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:12 4s/step - accuracy: 0.3008 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:06 4s/step - accuracy: 0.3010 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 24:01 4s/step - accuracy: 0.3013 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:57 4s/step - accuracy: 0.3015 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:52 4s/step - accuracy: 0.3018 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:48 4s/step - accuracy: 0.3020 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:45 4s/step - accuracy: 0.3022 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:41 4s/step - accuracy: 0.3024 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:38 4s/step - accuracy: 0.3027 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:33 4s/step - accuracy: 0.3029 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:28 4s/step - accuracy: 0.3031 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:23 4s/step - accuracy: 0.3033 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:18 4s/step - accuracy: 0.3035 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 23:13 4s/step - ac ...
# Epoch 12/50
# ...
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2:17:34 21s/step - accuracy: 0.3929 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 39:11 6s/step - accuracy: 0.4107 - loss: 0.1429  ━━━━━━━━━━━━━━━━━━━━ 38:20 6s/step - accuracy: 0.4233 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 38:51 6s/step - accuracy: 0.4320 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 40:12 6s/step - accuracy: 0.4394 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 39:29 6s/step - accuracy: 0.4446 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 38:44 6s/step - accuracy: 0.4484 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 38:10 6s/step - accuracy: 0.4511 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 37:46 6s/step - accuracy: 0.4537 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 37:27 6s/step - accuracy: 0.4569 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 37:26 6s/step - accuracy: 0.4598 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 37:21 6s/step - accuracy: 0.4625 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 37:29 6s/step - accuracy: 0.4645 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 37:36 6s/step - accuracy: 0.4662 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 37:27 6s/step - accuracy: 0.4673 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 37:27 6s/step - accuracy: 0.4683 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 37:10 6s/step - accuracy: 0.4692 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 36:53 6s/step - accuracy: 0.4700 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 36:37 6s/step - accuracy: 0.4708 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 36:23 6s/step - accuracy: 0.4715 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 36:13 6s/step - accuracy: 0.4722 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 36:22 6s/step - accuracy: 0.4728 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 36:34 6s/step - accuracy: 0.4732 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 36:36 6s/step - accuracy: 0.4735 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 36:14 6s/step - accuracy: 0.4736 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 35:54 6s/step - accuracy: 0.4737 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 35:35 6s/step - accuracy: 0.4739 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 35:16 6s/step - accuracy: 0.4741 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 34:58 6s/step - accuracy: 0.4743 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 34:40 6s/step - accuracy: 0.4745 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 34:28 6s/step - accuracy: 0.4748 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 34:14 6s/step - accuracy: 0.4750 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 33:59 6s/step - accuracy: 0.4751 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 33:44 6s/step - accuracy: 0.4753 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 33:30 6s/step - accuracy: 0.4754 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 33:16 6s/step - accuracy: 0.4755 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 33:04 6s/step - accuracy: 0.4756 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:52 6s/step - accuracy: 0.4758 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:40 6s/step - accuracy: 0.4759 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:28 6s/step - accuracy: 0.4759 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:17 6s/step - accuracy: 0.4759 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:05 6s/step - accuracy: 0.4760 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:54 6s/step - accuracy: 0.4760 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:43 5s/step - accuracy: 0.4761 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:32 5s/step - accuracy: 0.4761 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:22 5s/step - accuracy: 0.4761 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:11 5s/step - accuracy: 0.4761 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:01 5s/step - accuracy: 0.4762 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:51 5s/step - accuracy: 0.4762 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:41 5s/step - accuracy: 0.4763 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:32 5s/step - accuracy: 0.4763 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:23 5s/step - accuracy: 0.4764 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:14 5s/step - accuracy: 0.4765 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:05 5s/step - accuracy: 0.4766 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:57 5s/step - accuracy: 0.4766 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:48 5s/step - accuracy: 0.4766 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:40 5s/step - accuracy: 0.4766 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:31 5s/step - accuracy: 0.4766 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:24 5s/step - accuracy: 0.4766 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:17 5s/st ...
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1:04:57 10s/step - accuracy: 0.5476 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 34:16 5s/step - accuracy: 0.5298 - loss: 0.1429  ━━━━━━━━━━━━━━━━━━━━ 33:06 5s/step - accuracy: 0.5198 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:49 5s/step - accuracy: 0.5126 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:50 5s/step - accuracy: 0.5106 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:38 5s/step - accuracy: 0.5095 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:33 5s/step - accuracy: 0.5098 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:23 5s/step - accuracy: 0.5088 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:19 5s/step - accuracy: 0.5084 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:11 5s/step - accuracy: 0.5084 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 32:04 5s/step - accuracy: 0.5079 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:57 5s/step - accuracy: 0.5083 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:49 5s/step - accuracy: 0.5083 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:42 5s/step - accuracy: 0.5081 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:35 5s/step - accuracy: 0.5079 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:33 5s/step - accuracy: 0.5074 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:28 5s/step - accuracy: 0.5066 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:23 5s/step - accuracy: 0.5059 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:16 5s/step - accuracy: 0.5051 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:10 5s/step - accuracy: 0.5044 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 31:06 5s/step - accuracy: 0.5037 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:56 5s/step - accuracy: 0.5030 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:44 5s/step - accuracy: 0.5024 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:35 5s/step - accuracy: 0.5017 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:39 5s/step - accuracy: 0.5011 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:35 5s/step - accuracy: 0.5004 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:35 5s/step - accuracy: 0.4998 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:28 5s/step - accuracy: 0.4992 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:27 5s/step - accuracy: 0.4986 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:26 5s/step - accuracy: 0.4981 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:44 5s/step - accuracy: 0.4976 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:40 5s/step - accuracy: 0.4972 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:35 5s/step - accuracy: 0.4968 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:31 5s/step - accuracy: 0.4965 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:26 5s/step - accuracy: 0.4961 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:21 5s/step - accuracy: 0.4958 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:17 5s/step - accuracy: 0.4956 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:12 5s/step - accuracy: 0.4953 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:07 5s/step - accuracy: 0.4951 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:03 5s/step - accuracy: 0.4949 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:58 5s/step - accuracy: 0.4947 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:54 5s/step - accuracy: 0.4945 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:50 5s/step - accuracy: 0.4943 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:45 5s/step - accuracy: 0.4940 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:40 5s/step - accuracy: 0.4938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:36 5s/step - accuracy: 0.4935 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:31 5s/step - accuracy: 0.4933 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:26 5s/step - accuracy: 0.4931 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:21 5s/step - accuracy: 0.4928 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:16 5s/step - accuracy: 0.4926 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:11 5s/step - accuracy: 0.4924 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:06 5s/step - accuracy: 0.4922 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:01 5s/step - accuracy: 0.4920 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:57 5s/step - accuracy: 0.4918 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:52 5s/step - accuracy: 0.4916 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:47 5s/step - accuracy: 0.4914 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:42 5s/step - accuracy: 0.4912 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:37 5s/step - accuracy: 0.4910 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:32 5s/step - accuracy: 0.4908 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:27 5s/st ...
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1:04:14 10s/step - accuracy: 0.4643 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 31:09 5s/step - accuracy: 0.4583 - loss: 0.1429  ━━━━━━━━━━━━━━━━━━━━ 30:26 5s/step - accuracy: 0.4590 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:20 5s/step - accuracy: 0.4633 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:21 5s/step - accuracy: 0.4616 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:13 5s/step - accuracy: 0.4644 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 30:01 5s/step - accuracy: 0.4653 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:49 5s/step - accuracy: 0.4669 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:44 5s/step - accuracy: 0.4685 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:43 5s/step - accuracy: 0.4709 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:34 5s/step - accuracy: 0.4740 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:25 5s/step - accuracy: 0.4767 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:15 5s/step - accuracy: 0.4789 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:05 5s/step - accuracy: 0.4810 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:01 5s/step - accuracy: 0.4830 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 29:00 5s/step - accuracy: 0.4841 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:56 5s/step - accuracy: 0.4852 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:48 5s/step - accuracy: 0.4859 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:40 5s/step - accuracy: 0.4868 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:33 5s/step - accuracy: 0.4876 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:31 5s/step - accuracy: 0.4880 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:31 5s/step - accuracy: 0.4885 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:28 5s/step - accuracy: 0.4887 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:21 5s/step - accuracy: 0.4888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:15 5s/step - accuracy: 0.4891 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:11 5s/step - accuracy: 0.4892 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:08 5s/step - accuracy: 0.4893 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:06 5s/step - accuracy: 0.4893 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:03 5s/step - accuracy: 0.4892 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 28:01 5s/step - accuracy: 0.4891 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:55 5s/step - accuracy: 0.4891 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:48 5s/step - accuracy: 0.4891 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:42 5s/step - accuracy: 0.4891 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:37 5s/step - accuracy: 0.4890 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:33 5s/step - accuracy: 0.4890 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:28 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:25 5s/step - accuracy: 0.4890 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:21 5s/step - accuracy: 0.4890 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:18 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:14 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:11 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:07 5s/step - accuracy: 0.4888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 27:02 5s/step - accuracy: 0.4888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:55 5s/step - accuracy: 0.4888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:49 5s/step - accuracy: 0.4888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:43 5s/step - accuracy: 0.4888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:39 5s/step - accuracy: 0.4888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:36 5s/step - accuracy: 0.4888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:32 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:28 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:24 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:20 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:16 5s/step - accuracy: 0.4890 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:12 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:09 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:05 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 26:01 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:56 5s/step - accuracy: 0.4889 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:51 5s/step - accuracy: 0.4888 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 25:46 5s/st ...

# %%
student_model.save('Trained Model/LEC_model_student.keras')
