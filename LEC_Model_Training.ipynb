# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import gc
import h5py
import wandb
import sys
import matplotlib.pyplot as plt 
from tensorflow.keras.models import load_model
from dotenv import load_dotenv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras.applications import MobileNetV2, MobileNetV3Small, MobileNetV3Large
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import KLDivergence
from tensorflow.keras.layers import Input
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Layer, GlobalAveragePooling2D, Reshape, Dense, Multiply, Conv2D, Add, Activation, BatchNormalization
from tensorflow.keras.applications import MobileNetV3Small

# %%
load_dotenv()  # Load environment variables from .env file
api_key = os.getenv("WANDB_API_KEY")

wandb.login(key=api_key)  # Login with the API key
wandb.init(project="LEC_FER2013", entity=os.getenv("WANDB_USERNAME"))
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: nicholas66. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.1
# Run data is saved locally in <code>n:\Thesis 2\Code\wandb\run-20241217_223336-wkzhibf3</code>
# Syncing run <strong><a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/wkzhibf3' target="_blank">whole-rain-28</a></strong> to <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nicholas66/LEC_FER2013' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013</a>
#  View run at <a href='https://wandb.ai/nicholas66/LEC_FER2013/runs/wkzhibf3' target="_blank">https://wandb.ai/nicholas66/LEC_FER2013/runs/wkzhibf3</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/nicholas66/LEC_FER2013/runs/wkzhibf3?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def load_data(hdf5_file, dataset_name_images, dataset_name_labels):
    with h5py.File(hdf5_file, 'r') as hf:
        data = np.array(hf[dataset_name_images])
        labels = np.array(hf[dataset_name_labels])
    return data, labels

# Load data
data, labels = load_data('output files/fer2013_processed.h5', 'fer2013_images', 'fer2013_labels')

# Print shapes to verify
print(f"Data shape: {data.shape}")
print(f"Labels shape: {labels.shape}")

# Ensure that data and labels are not empty
assert len(data) > 0, "Data is empty."
assert len(labels) > 0, "Labels are empty."

# Split data
X_train, X_val, y_train, y_val = train_test_split(
    data, 
    labels, 
    test_size=0.2, 
    stratify=labels
)

# Print shapes of the split data
print(f"Training data shape: {X_train.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Validation data shape: {X_val.shape}")
print(f"Validation labels shape: {y_val.shape}")
# Out:
# Data shape: (28709, 224, 224, 3)
# Labels shape: (28709,)
# Training data shape: (22967, 224, 224, 3)
# Training labels shape: (22967,)
# Validation data shape: (5742, 224, 224, 3)
# Validation labels shape: (5742,)

# %%
# Define the data augmentation transformations
train_datagen = ImageDataGenerator(
    rotation_range=20,         # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,     # Randomly shift images horizontally by up to 20% of the width
    height_shift_range=0.2,    # Randomly shift images vertically by up to 20% of the height
    shear_range=0.2,           # Randomly apply shearing transformation
    zoom_range=0.2,            # Randomly zoom images by up to 20%
    horizontal_flip=True,      # Randomly flip images horizontally
    fill_mode='nearest'        # Strategy for filling in newly created pixels
)

# Create data generator for training data
train_generator = train_datagen.flow(
    X_train,   # Training images
    y_train,   # Training labels
    batch_size=64  # Batch size for training
)

validation_datagen = ImageDataGenerator()

# Create data generator for validation data
validation_generator = validation_datagen.flow(
    X_val,  # Validation images
    y_val,  # Validation labels
    batch_size=64   # Batch size for validation
)

# %% [markdown]
# # Teacher Model

# %%
# def create_teacher_model():
#     base_model = EfficientNetB4(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#     base_model.trainable = False  # Freeze the EfficientNet model
    
#     # Build teacher model
#     model = Sequential([
#         base_model,
#         GlobalAveragePooling2D(),
#         Dense(128, activation='relu'),
#         Dense(64, activation='relu'),
#         Dense(7, activation='softmax')  # 7 emotion classes
#     ])
#     return model

def create_teacher_model():
    # Load the local MobileNetV3 model
    model = load_model("Trained Model/Teacher_MobileNetV3Large_model.keras")
    model.trainable = False  # Freeze the model layers
    
    return model

# %%
# Channel Attention Module
class ChannelAttention(Layer):
    def __init__(self, reduction_ratio=16, **kwargs):
        super(ChannelAttention, self).__init__(**kwargs)
        self.reduction_ratio = reduction_ratio

    def build(self, input_shape):
        self.global_avg_pool = GlobalAveragePooling2D()
        self.reshape = Reshape((1, 1, input_shape[-1]))
        self.dense1 = Dense(input_shape[-1] // self.reduction_ratio, activation='relu', use_bias=False)
        self.dense2 = Dense(input_shape[-1], activation='sigmoid', use_bias=False)

    def call(self, inputs):
        x = self.global_avg_pool(inputs)
        x = self.reshape(x)
        x = self.dense1(x)
        x = self.dense2(x)
        return Multiply()([inputs, x])


# Spatial Attention Module
class SpatialAttention(Layer):
    def __init__(self, kernel_size=7, **kwargs):
        super(SpatialAttention, self).__init__(**kwargs)
        self.conv = Conv2D(1, kernel_size, padding='same', activation='sigmoid')

    def call(self, inputs):
        avg_pool = tf.reduce_mean(inputs, axis=-1, keepdims=True)
        max_pool = tf.reduce_max(inputs, axis=-1, keepdims=True)
        concat = tf.concat([avg_pool, max_pool], axis=-1)
        return Multiply()([inputs, self.conv(concat)])

# CBAM Module
class CBAM(Layer):
    def __init__(self, reduction_ratio=16, kernel_size=7, **kwargs):
        super(CBAM, self).__init__(**kwargs)
        self.channel_attention = ChannelAttention(reduction_ratio=reduction_ratio)
        self.spatial_attention = SpatialAttention(kernel_size=kernel_size)

    def call(self, inputs):
        x = self.channel_attention(inputs)
        x = self.spatial_attention(x)
        return x

# %% [markdown]
# # LEC Model (Student)

# %%
def create_student_model():
    base_model = MobileNetV3Small(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
    # Set all layers in base_model to be trainable
    for layer in base_model.layers: 
        layer.trainable = True
    
    # Define the model input and output
    inputs = base_model.input
    x = base_model.output  # Extract original output
    
    # Add CBAM to specific layers (e.g., after the last convolutional block)
    x = CBAM(reduction_ratio=16)(x)
    
    # Add custom classification layers
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(7, activation='softmax')(x)  # Assuming 7 classes
    
    # Reassemble the model
    model = Model(inputs=inputs, outputs=outputs)

    return model

model = create_student_model()

# %%
teacher_model = create_teacher_model()
student_model = create_student_model()

# Custom callback for WandB
class WandBCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        wandb.log({
            "Training Loss": logs.get("loss"),
            "Training Accuracy": logs.get("accuracy"),
            "Val Loss": logs.get("val_loss"),
            "Val Accuracy": logs.get("val_accuracy"),
            "epoch": epoch + 1
        })



        

# Define the knowledge distillation loss function
def knowledge_distillation_loss(y_true, y_pred, teacher_logits, T=3, alpha=0.5):
    
    # Hard loss (real labels)
    hard_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    # Soft loss (teacher predictions)
    soft_loss = KLDivergence()(
        tf.nn.softmax(teacher_logits / T),
        tf.nn.softmax(y_pred / T)
    )
    # Combined loss
    return alpha * hard_loss + (1 - alpha) * soft_loss

# %%
# reduce_lr = ReduceLROnPlateau(
#     monitor='val_loss',  # Metric to monitor, e.g., validation loss
#     factor=0.5,          # Factor by which the learning rate will be reduced
#     patience=5,          # Number of epochs with no improvement before reducing LR
#     min_lr=1e-8,         # Lower bound for the learning rate
# )

from tensorflow.keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
    if epoch > 0 and epoch % 20 == 0:  # Every 20 epochs
        return lr * 0.5                # Reduce LR by factor of 0.5
    return lr

reduce_lr = LearningRateScheduler(scheduler, verbose=1)

# %%
# Custom training step for batch-wise teacher logits
class CustomDistillationModel(tf.keras.Model):
    def __init__(self, student, teacher):
        super(CustomDistillationModel, self).__init__()
        self.student = student
        self.teacher = teacher

    def call(self, inputs, training=False):
        return self.student(inputs, training=training)

    def train_step(self, data):
        x, y_true = data
        
        # Get teacher predictions for the current batch
        teacher_logits = self.teacher(x, training=False)
        # tf.print("Sample teacher_logits:", teacher_logits[:5])

        with tf.GradientTape() as tape:
            # Student predictions
            y_pred = self.student(x, training=True)
            # Compute the KD loss
            loss = knowledge_distillation_loss(y_true, y_pred, teacher_logits)

        # Compute gradients and update weights
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update metrics (accuracy)
        self.compiled_metrics.update_state(y_true, y_pred)

        logs = {m.name: m.result() for m in self.metrics}

        return logs

# Create the custom KD model
distilled_model = CustomDistillationModel(student_model, teacher_model)

# Compile the student model (no need to modify the WandB callback)
distilled_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model as before

# %%
history = distilled_model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    callbacks=[WandBCallback(), reduce_lr],  # Add reduce_lr callback here
    verbose=1
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/100
# n:\Thesis 2\Code\myenv\lib\site-packages\keras\src\backend\tensorflow\trainer.py:578: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# n:\Thesis 2\Code\myenv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 2:20:29 24s/step - accuracy: 0.1562 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 10:32 2s/step - accuracy: 0.1367 - loss: 0.1429  ━━━━━━━━━━━━━━━━━━━━ 11:15 2s/step - accuracy: 0.1259 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:29 2s/step - accuracy: 0.1266 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:18 2s/step - accuracy: 0.1251 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:17 2s/step - accuracy: 0.1246 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:12 2s/step - accuracy: 0.1256 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:05 2s/step - accuracy: 0.1275 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:02 2s/step - accuracy: 0.1291 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:57 2s/step - accuracy: 0.1311 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:56 2s/step - accuracy: 0.1328 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:54 2s/step - accuracy: 0.1340 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:54 2s/step - accuracy: 0.1351 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:53 2s/step - accuracy: 0.1362 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:52 2s/step - accuracy: 0.1373 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.1380 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:46 2s/step - accuracy: 0.1386 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:43 2s/step - accuracy: 0.1390 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:40 2s/step - accuracy: 0.1396 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:39 2s/step - accuracy: 0.1402 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:37 2s/step - accuracy: 0.1408 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:34 2s/step - accuracy: 0.1414 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:33 2s/step - accuracy: 0.1423 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:33 2s/step - accuracy: 0.1430 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:31 2s/step - accuracy: 0.1438 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:29 2s/step - accuracy: 0.1445 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:26 2s/step - accuracy: 0.1453 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:26 2s/step - accuracy: 0.1460 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:25 2s/step - accuracy: 0.1466 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:23 2s/step - accuracy: 0.1472 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - accuracy: 0.1478 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:21 2s/step - accuracy: 0.1483 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - accuracy: 0.1488 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:19 2s/step - accuracy: 0.1493 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.1498 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.1503 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.1508 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:15 2s/step - accuracy: 0.1512 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.1516 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:11 2s/step - accuracy: 0.1520 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:11 2s/step - accuracy: 0.1524 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.1528 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.1532 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.1536 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.1540 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.1545 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.1549 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.1553 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.1557 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.1561 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.1565 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.1569 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.1573 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.1577 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.1581 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.1585 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.1588 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.1592 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.1595 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/st ...
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 30:38 5s/step - accuracy: 0.3125 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:25 2s/step - accuracy: 0.3008 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:30 2s/step - accuracy: 0.2995 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:18 2s/step - accuracy: 0.2998 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:10 2s/step - accuracy: 0.2973 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:07 2s/step - accuracy: 0.2955 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:03 2s/step - accuracy: 0.2941 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:02 2s/step - accuracy: 0.2920 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:00 2s/step - accuracy: 0.2906 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:56 2s/step - accuracy: 0.2899 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:52 2s/step - accuracy: 0.2893 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:49 2s/step - accuracy: 0.2893 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.2893 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.2896 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:46 2s/step - accuracy: 0.2898 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:45 2s/step - accuracy: 0.2899 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:42 2s/step - accuracy: 0.2900 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:41 2s/step - accuracy: 0.2902 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:38 2s/step - accuracy: 0.2902 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:37 2s/step - accuracy: 0.2902 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:34 2s/step - accuracy: 0.2900 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:32 2s/step - accuracy: 0.2899 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:30 2s/step - accuracy: 0.2898 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:28 2s/step - accuracy: 0.2899 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:25 2s/step - accuracy: 0.2901 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:23 2s/step - accuracy: 0.2903 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:21 2s/step - accuracy: 0.2905 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:19 2s/step - accuracy: 0.2908 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:17 2s/step - accuracy: 0.2911 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.2912 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:15 2s/step - accuracy: 0.2913 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:15 2s/step - accuracy: 0.2914 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.2915 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:11 2s/step - accuracy: 0.2916 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.2917 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.2918 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.2919 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.2919 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.2920 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.2920 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.2921 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.2921 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.2922 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.2923 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.2924 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.2924 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.2925 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.2926 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.2927 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.2928 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.2929 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.2930 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.2931 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.2932 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - accuracy: 0.2933 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.2934 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.2935 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.2936 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.2938 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - ac ...
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 29:28 5s/step - accuracy: 0.4844 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:04 2s/step - accuracy: 0.5078 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:16 2s/step - accuracy: 0.5017 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:22 2s/step - accuracy: 0.4906 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:27 2s/step - accuracy: 0.4831 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:26 2s/step - accuracy: 0.4763 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:29 2s/step - accuracy: 0.4702 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:24 2s/step - accuracy: 0.4651 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:20 2s/step - accuracy: 0.4605 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:18 2s/step - accuracy: 0.4560 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:15 2s/step - accuracy: 0.4526 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:12 2s/step - accuracy: 0.4500 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:09 2s/step - accuracy: 0.4478 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:07 2s/step - accuracy: 0.4463 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:05 2s/step - accuracy: 0.4450 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:02 2s/step - accuracy: 0.4439 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:59 2s/step - accuracy: 0.4433 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - accuracy: 0.4427 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:51 2s/step - accuracy: 0.4421 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:48 2s/step - accuracy: 0.4417 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:45 2s/step - accuracy: 0.4414 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:43 2s/step - accuracy: 0.4412 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:40 2s/step - accuracy: 0.4410 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:39 2s/step - accuracy: 0.4407 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:38 2s/step - accuracy: 0.4402 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:35 2s/step - accuracy: 0.4398 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:32 2s/step - accuracy: 0.4396 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:30 2s/step - accuracy: 0.4394 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:27 2s/step - accuracy: 0.4391 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - accuracy: 0.4388 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:21 2s/step - accuracy: 0.4386 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.4384 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:15 2s/step - accuracy: 0.4381 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.4379 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:11 2s/step - accuracy: 0.4376 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.4373 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.4371 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.4368 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.4366 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.4364 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.4361 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - accuracy: 0.4359 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.4356 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - accuracy: 0.4355 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.4353 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.4351 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.4349 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.4348 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.4346 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.4344 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.4343 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.4341 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.4340 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.4338 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - accuracy: 0.4337 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.4335 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.4334 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.4332 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.4331 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - ac ...
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 26:17 4s/step - accuracy: 0.4531 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.4366 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.4368 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.4400 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.4439 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.4482 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.4518 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.4560 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.4602 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.4627 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.4653 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.4680 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.4694 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.4708 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - accuracy: 0.4719 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.4730 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.4738 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.4745 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - accuracy: 0.4750 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - accuracy: 0.4755 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.4760 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.4764 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.4764 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.4764 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:09 2s/step - accuracy: 0.4764 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.4762 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - accuracy: 0.4761 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.4760 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.4759 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.4758 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.4757 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.4757 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.4757 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - accuracy: 0.4757 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - accuracy: 0.4757 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.4756 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.4755 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - accuracy: 0.4754 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.4752 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - accuracy: 0.4750 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.4748 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:41 2s/step - accuracy: 0.4746 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.4744 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.4742 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.4740 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.4739 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - accuracy: 0.4737 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - accuracy: 0.4737 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - accuracy: 0.4736 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - accuracy: 0.4736 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:30 2s/step - accuracy: 0.4735 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.4735 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:28 2s/step - accuracy: 0.4734 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:26 2s/step - accuracy: 0.4734 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:25 2s/step - accuracy: 0.4734 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:23 2s/step - accuracy: 0.4734 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:22 2s/step - accuracy: 0.4734 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:20 2s/step - accuracy: 0.4734 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:19 2s/step - accuracy: 0.4734 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:17 2s/step - ac ...
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23:52 4s/step - accuracy: 0.4688 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - accuracy: 0.4805 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.4922 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - accuracy: 0.5020 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.5091 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.5141 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.5162 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.5171 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.5169 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - accuracy: 0.5160 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.5152 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.5146 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.5146 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.5149 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.5149 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.5154 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.5158 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.5157 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.5158 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.5157 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.5156 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:02 2s/step - accuracy: 0.5152 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.5148 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.5144 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.5140 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - accuracy: 0.5136 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.5132 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:52 2s/step - accuracy: 0.5127 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.5121 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.5116 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:47 2s/step - accuracy: 0.5112 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.5108 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - accuracy: 0.5106 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.5103 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.5101 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.5099 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.5097 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.5096 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.5095 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:33 2s/step - accuracy: 0.5093 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - accuracy: 0.5090 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:30 2s/step - accuracy: 0.5088 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.5086 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:28 2s/step - accuracy: 0.5085 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:26 2s/step - accuracy: 0.5083 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:25 2s/step - accuracy: 0.5082 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:23 2s/step - accuracy: 0.5081 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:22 2s/step - accuracy: 0.5080 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:20 2s/step - accuracy: 0.5079 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:19 2s/step - accuracy: 0.5079 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:17 2s/step - accuracy: 0.5078 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:16 2s/step - accuracy: 0.5078 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:14 2s/step - accuracy: 0.5077 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:13 2s/step - accuracy: 0.5077 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:11 2s/step - accuracy: 0.5076 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:10 2s/step - accuracy: 0.5075 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:08 2s/step - accuracy: 0.5075 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:07 2s/step - accuracy: 0.5074 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:05 2s/step - accuracy: 0.5074 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:03 2s/step - ac ...
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 6/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 24:55 4s/step - accuracy: 0.5312 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.5586 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.5616 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - accuracy: 0.5599 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.5579 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.5569 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.5545 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.5524 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.5491 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.5477 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.5464 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.5451 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.5434 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.5415 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.5398 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.5379 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.5364 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.5350 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.5340 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.5330 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.5320 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.5311 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.5303 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - accuracy: 0.5295 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.5289 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - accuracy: 0.5283 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.5278 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - accuracy: 0.5273 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.5270 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.5267 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.5264 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.5262 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:09 2s/step - accuracy: 0.5261 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.5260 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.5260 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:04 2s/step - accuracy: 0.5260 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:02 2s/step - accuracy: 0.5260 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.5260 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.5260 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.5260 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - accuracy: 0.5261 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.5261 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:52 2s/step - accuracy: 0.5260 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:50 2s/step - accuracy: 0.5259 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - accuracy: 0.5258 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:47 2s/step - accuracy: 0.5257 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.5255 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.5254 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.5253 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.5252 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - accuracy: 0.5250 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.5249 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.5247 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:33 2s/step - accuracy: 0.5245 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - accuracy: 0.5244 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.5242 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:28 2s/step - accuracy: 0.5240 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:26 2s/step - accuracy: 0.5238 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:24 2s/step - accuracy: 0.5237 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:23 2s/step - ac ...
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 7/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 27:16 5s/step - accuracy: 0.4531 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:41 2s/step - accuracy: 0.4766 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:26 2s/step - accuracy: 0.4878 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.4919 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:17 2s/step - accuracy: 0.4947 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.4943 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:08 2s/step - accuracy: 0.4964 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.4978 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.4990 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.5013 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.5039 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - accuracy: 0.5056 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.5070 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - accuracy: 0.5085 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.5099 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.5112 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.5123 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.5133 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.5140 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.5145 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.5150 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.5155 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.5162 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.5169 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.5176 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.5184 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.5192 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.5198 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.5203 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.5207 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.5209 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - accuracy: 0.5210 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.5212 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.5213 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.5214 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.5215 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.5217 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.5219 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.5222 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - accuracy: 0.5224 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.5226 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.5228 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.5230 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.5232 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.5234 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.5236 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - accuracy: 0.5239 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - accuracy: 0.5240 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.5242 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.5243 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:47 2s/step - accuracy: 0.5244 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.5246 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - accuracy: 0.5247 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.5249 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:41 2s/step - accuracy: 0.5250 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.5252 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - accuracy: 0.5253 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.5255 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.5257 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:33 2s/step - ac ...
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 8/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 25:24 4s/step - accuracy: 0.5156 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:21 2s/step - accuracy: 0.5234 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:13 2s/step - accuracy: 0.5312 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.5293 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:06 2s/step - accuracy: 0.5347 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.5372 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:02 2s/step - accuracy: 0.5369 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.5382 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.5393 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.5404 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - accuracy: 0.5415 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.5422 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.5431 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.5440 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.5446 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.5454 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.5459 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.5466 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.5471 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.5475 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - accuracy: 0.5480 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.5484 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - accuracy: 0.5487 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - accuracy: 0.5491 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.5496 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.5500 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.5502 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.5505 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.5508 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.5511 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.5514 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.5518 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:04 2s/step - accuracy: 0.5521 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.5524 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.5527 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.5530 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.5533 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.5535 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.5537 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - accuracy: 0.5539 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.5542 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:50 2s/step - accuracy: 0.5545 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.5547 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:47 2s/step - accuracy: 0.5549 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.5550 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - accuracy: 0.5551 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.5551 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:41 2s/step - accuracy: 0.5552 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.5553 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.5554 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - accuracy: 0.5555 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.5556 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.5557 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:35 2s/step - accuracy: 0.5558 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:33 2s/step - accuracy: 0.5559 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - accuracy: 0.5560 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:30 2s/step - accuracy: 0.5561 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:28 2s/step - accuracy: 0.5562 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:27 2s/step - accuracy: 0.5563 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:25 2s/step - ac ...
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 9/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 24:25 4s/step - accuracy: 0.5938 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.5938 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.5851 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - accuracy: 0.5814 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.5795 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.5753 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:47 2s/step - accuracy: 0.5745 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.5754 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.5761 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.5761 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.5766 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.5764 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.5767 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.5771 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.5775 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - accuracy: 0.5777 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.5777 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.5776 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.5775 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.5773 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.5772 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - accuracy: 0.5771 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:04 2s/step - accuracy: 0.5771 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:02 2s/step - accuracy: 0.5770 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.5769 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.5768 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.5767 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.5765 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.5763 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - accuracy: 0.5762 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.5759 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:49 2s/step - accuracy: 0.5757 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - accuracy: 0.5754 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.5751 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - accuracy: 0.5748 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.5744 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.5740 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - accuracy: 0.5737 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.5734 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.5732 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:35 2s/step - accuracy: 0.5729 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.5727 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - accuracy: 0.5725 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - accuracy: 0.5723 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.5721 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:27 2s/step - accuracy: 0.5720 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:25 2s/step - accuracy: 0.5719 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:23 2s/step - accuracy: 0.5717 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:22 2s/step - accuracy: 0.5716 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:20 2s/step - accuracy: 0.5715 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:18 2s/step - accuracy: 0.5714 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:17 2s/step - accuracy: 0.5712 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:15 2s/step - accuracy: 0.5711 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:13 2s/step - accuracy: 0.5710 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:11 2s/step - accuracy: 0.5708 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:10 2s/step - accuracy: 0.5707 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:08 2s/step - accuracy: 0.5705 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:06 2s/step - accuracy: 0.5703 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:05 2s/step - accuracy: 0.5702 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:03 2s/step - a ...
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 10/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 25:50 4s/step - accuracy: 0.6875 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.6875 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.6736 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.6605 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - accuracy: 0.6515 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - accuracy: 0.6454 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.6415 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - accuracy: 0.6380 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.6340 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.6306 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.6275 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.6243 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - accuracy: 0.6213 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - accuracy: 0.6189 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.6169 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.6151 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.6133 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.6120 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.6107 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.6095 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:09 2s/step - accuracy: 0.6083 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.6071 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - accuracy: 0.6061 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.6050 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.6041 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.6033 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - accuracy: 0.6027 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.6022 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.6015 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:52 2s/step - accuracy: 0.6009 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:50 2s/step - accuracy: 0.6002 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - accuracy: 0.5995 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.5988 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.5981 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.5974 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.5968 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.5962 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - accuracy: 0.5955 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.5948 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - accuracy: 0.5942 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.5936 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:33 2s/step - accuracy: 0.5931 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - accuracy: 0.5925 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.5920 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:28 2s/step - accuracy: 0.5916 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:26 2s/step - accuracy: 0.5911 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:24 2s/step - accuracy: 0.5907 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:23 2s/step - accuracy: 0.5902 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:21 2s/step - accuracy: 0.5897 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:19 2s/step - accuracy: 0.5893 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:18 2s/step - accuracy: 0.5889 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:16 2s/step - accuracy: 0.5885 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:14 2s/step - accuracy: 0.5881 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:13 2s/step - accuracy: 0.5877 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:11 2s/step - accuracy: 0.5874 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:09 2s/step - accuracy: 0.5871 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:08 2s/step - accuracy: 0.5868 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:06 2s/step - accuracy: 0.5865 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:05 2s/step - accuracy: 0.5862 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:03 2s/step - ac ...
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 11/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 24:00 4s/step - accuracy: 0.5469 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.5781 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:32 2s/step - accuracy: 0.5972 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.6012 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.6041 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - accuracy: 0.6063 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - accuracy: 0.6067 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.6071 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - accuracy: 0.6073 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - accuracy: 0.6074 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.6078 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.6080 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:13 2s/step - accuracy: 0.6076 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - accuracy: 0.6072 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.6070 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.6063 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - accuracy: 0.6056 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - accuracy: 0.6052 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:04 2s/step - accuracy: 0.6052 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.6052 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.6051 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.6050 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.6048 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.6047 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:56 2s/step - accuracy: 0.6044 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:54 2s/step - accuracy: 0.6041 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - accuracy: 0.6038 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:52 2s/step - accuracy: 0.6036 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:50 2s/step - accuracy: 0.6035 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - accuracy: 0.6032 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - accuracy: 0.6030 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.6029 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - accuracy: 0.6027 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.6024 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.6022 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - accuracy: 0.6020 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.6018 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:35 2s/step - accuracy: 0.6017 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - accuracy: 0.6016 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - accuracy: 0.6015 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:30 2s/step - accuracy: 0.6014 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - accuracy: 0.6014 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:27 2s/step - accuracy: 0.6014 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:26 2s/step - accuracy: 0.6013 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:24 2s/step - accuracy: 0.6012 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:22 2s/step - accuracy: 0.6010 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:21 2s/step - accuracy: 0.6009 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:19 2s/step - accuracy: 0.6007 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:17 2s/step - accuracy: 0.6005 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:16 2s/step - accuracy: 0.6003 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:14 2s/step - accuracy: 0.6001 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:12 2s/step - accuracy: 0.5999 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:11 2s/step - accuracy: 0.5997 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:09 2s/step - accuracy: 0.5995 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:07 2s/step - accuracy: 0.5993 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:06 2s/step - accuracy: 0.5991 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:05 2s/step - accuracy: 0.5990 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:03 2s/step - accuracy: 0.5988 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:01 2s/step - accuracy: 0.5987 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:00 2s/step - ac ...
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 12/100
# ...
#
# Epoch 53: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 53/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 32:50 6s/step - accuracy: 0.8281 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:17 2s/step - accuracy: 0.8047 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:11 2s/step - accuracy: 0.7847 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:34 2s/step - accuracy: 0.7712 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:38 2s/step - accuracy: 0.7582 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:30 2s/step - accuracy: 0.7499 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:21 2s/step - accuracy: 0.7451 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:19 2s/step - accuracy: 0.7423 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:21 2s/step - accuracy: 0.7405 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:19 2s/step - accuracy: 0.7386 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:17 2s/step - accuracy: 0.7368 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:12 2s/step - accuracy: 0.7347 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:07 2s/step - accuracy: 0.7335 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:06 2s/step - accuracy: 0.7329 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:02 2s/step - accuracy: 0.7329 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:59 2s/step - accuracy: 0.7330 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:57 2s/step - accuracy: 0.7326 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:56 2s/step - accuracy: 0.7323 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:56 2s/step - accuracy: 0.7319 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - accuracy: 0.7315 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - accuracy: 0.7309 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:49 2s/step - accuracy: 0.7303 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:49 2s/step - accuracy: 0.7297 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:49 2s/step - accuracy: 0.7290 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:48 2s/step - accuracy: 0.7284 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:46 2s/step - accuracy: 0.7279 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:45 2s/step - accuracy: 0.7276 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:43 2s/step - accuracy: 0.7273 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:42 2s/step - accuracy: 0.7270 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:40 2s/step - accuracy: 0.7267 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:38 2s/step - accuracy: 0.7266 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:37 2s/step - accuracy: 0.7264 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:36 2s/step - accuracy: 0.7264 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:34 2s/step - accuracy: 0.7263 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:32 2s/step - accuracy: 0.7262 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:30 2s/step - accuracy: 0.7261 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:29 2s/step - accuracy: 0.7260 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:28 2s/step - accuracy: 0.7260 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:26 2s/step - accuracy: 0.7259 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - accuracy: 0.7258 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - accuracy: 0.7257 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - accuracy: 0.7256 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.7255 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:17 2s/step - accuracy: 0.7254 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:14 2s/step - accuracy: 0.7254 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:12 2s/step - accuracy: 0.7253 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:10 2s/step - accuracy: 0.7253 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.7252 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.7252 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:06 2s/step - accuracy: 0.7252 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.7252 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.7252 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.7251 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - accuracy: 0.7251 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.7251 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - accuracy: 0.7251 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - accuracy: 0.7250 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.7250 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.7250 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - ac ...
#
# Epoch 54: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 54/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 28:34 5s/step - accuracy: 0.7812 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:59 2s/step - accuracy: 0.7734 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 11:02 2s/step - accuracy: 0.7674 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:57 2s/step - accuracy: 0.7640 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:57 2s/step - accuracy: 0.7637 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:58 2s/step - accuracy: 0.7632 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:54 2s/step - accuracy: 0.7625 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:51 2s/step - accuracy: 0.7612 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:50 2s/step - accuracy: 0.7598 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.7596 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.7595 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:46 2s/step - accuracy: 0.7592 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.7588 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:51 2s/step - accuracy: 0.7583 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:49 2s/step - accuracy: 0.7581 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - accuracy: 0.7578 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:45 2s/step - accuracy: 0.7573 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:43 2s/step - accuracy: 0.7569 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:41 2s/step - accuracy: 0.7564 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:40 2s/step - accuracy: 0.7558 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:38 2s/step - accuracy: 0.7551 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:36 2s/step - accuracy: 0.7546 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:34 2s/step - accuracy: 0.7541 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:32 2s/step - accuracy: 0.7534 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:30 2s/step - accuracy: 0.7530 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:28 2s/step - accuracy: 0.7526 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:26 2s/step - accuracy: 0.7522 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:25 2s/step - accuracy: 0.7517 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:23 2s/step - accuracy: 0.7513 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - accuracy: 0.7509 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - accuracy: 0.7503 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - accuracy: 0.7499 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - accuracy: 0.7494 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:14 2s/step - accuracy: 0.7489 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:12 2s/step - accuracy: 0.7485 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:10 2s/step - accuracy: 0.7481 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:08 2s/step - accuracy: 0.7478 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.7475 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:06 2s/step - accuracy: 0.7471 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - accuracy: 0.7467 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - accuracy: 0.7464 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:02 2s/step - accuracy: 0.7461 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.7458 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.7455 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - accuracy: 0.7453 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.7450 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.7448 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - accuracy: 0.7446 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.7444 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - accuracy: 0.7442 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.7440 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.7439 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:47 2s/step - accuracy: 0.7437 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - accuracy: 0.7436 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - accuracy: 0.7434 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.7432 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.7430 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.7429 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - accuracy: 0.7427 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - ac ...
#
# Epoch 55: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 55/100
# 133/359 ━━━━━━━━━━━━━━━━━━━━ 30:17 5s/step - accuracy: 0.7344 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:30 2s/step - accuracy: 0.7070 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:25 2s/step - accuracy: 0.6988 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:14 2s/step - accuracy: 0.7018 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - accuracy: 0.7065 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - accuracy: 0.7089 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:04 2s/step - accuracy: 0.7123 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - accuracy: 0.7140 - loss: 0.14 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - accuracy: 0.7153 - loss: 0.1429 ━━━━━━━━━━━━━━━━━━━━ 9:57 2s/step - accuracy: 0.7171 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.7190 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - accuracy: 0.7209 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.7224 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.7238 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - accuracy: 0.7249 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - accuracy: 0.7260 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:47 2s/step - accuracy: 0.7268 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:45 2s/step - accuracy: 0.7277 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - accuracy: 0.7285 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:42 2s/step - accuracy: 0.7292 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:40 2s/step - accuracy: 0.7300 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - accuracy: 0.7305 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - accuracy: 0.7308 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - accuracy: 0.7312 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - accuracy: 0.7314 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:30 2s/step - accuracy: 0.7316 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - accuracy: 0.7317 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:28 2s/step - accuracy: 0.7319 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - accuracy: 0.7320 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - accuracy: 0.7322 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:23 2s/step - accuracy: 0.7322 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - accuracy: 0.7322 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - accuracy: 0.7321 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - accuracy: 0.7319 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - accuracy: 0.7318 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - accuracy: 0.7316 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - accuracy: 0.7315 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - accuracy: 0.7314 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - accuracy: 0.7313 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:08 2s/step - accuracy: 0.7311 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:06 2s/step - accuracy: 0.7309 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:04 2s/step - accuracy: 0.7307 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - accuracy: 0.7306 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.7305 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - accuracy: 0.7303 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 9:01 2s/step - accuracy: 0.7301 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:59 2s/step - accuracy: 0.7300 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - accuracy: 0.7298 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - accuracy: 0.7297 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - accuracy: 0.7295 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - accuracy: 0.7293 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - accuracy: 0.7292 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:47 2s/step - accuracy: 0.7290 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:45 2s/step - accuracy: 0.7288 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - accuracy: 0.7287 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - accuracy: 0.7285 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:40 2s/step - accuracy: 0.7284 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - accuracy: 0.7282 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - accuracy: 0.7281 - loss: 0.142 ━━━━━━━━━━━━━━━━━━━━ 8:35 2s/step - ac ...

# %%
student_model.save('Trained Model/LEC_model.keras')

# %%
# Plotting training and validation accuracy
plt.figure(figsize=(10, 5))  # Create a new figure for the plot
plt.plot(history.history['accuracy'], label='Training Accuracy')  # Plot training accuracy
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Plot validation accuracy
plt.title('Training and Validation Accuracy')  # Title of the plot
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label
plt.legend()  # Show legend
plt.grid()  # Show grid
plt.show()  # Display the plot
